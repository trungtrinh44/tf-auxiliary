# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
# from elmo import elmo_embedding
import numpy as np
import os
from tqdm import tqdm
import json
import pickle
import logging
from utils import get_logger

# %%
def dan(inputs, labels, seq_lens, n_layers, n_units, n_classes, dropout, name='classifier', is_training=True, reuse=False):
    with tf.variable_scope(name, reuse=reuse):
        inputs = tf.reduce_sum(inputs, axis=1, keepdims=False)
        for i in range(n_layers):
            W = tf.get_variable(name='W_{}'.format(i), shape=(inputs.shape[-1], n_units), trainable=True, initializer=tf.glorot_uniform_initializer())
            b = tf.get_variable(name='b_{}'.format(i), shape=(n_units,), trainable=True, initializer=tf.zeros_initializer())
            outputs = tf.nn.xw_plus_b(inputs, W, b, name='dense_{}'.format(i))
            if is_training:
                outputs = tf.nn.dropout(outputs, keep_prob=1.0-dropout)
            inputs = outputs
        W = tf.get_variable(name='W_out', shape=(inputs.shape[-1], n_classes), trainable=True, initializer=tf.glorot_uniform_initializer())
        b = tf.get_variable(name='b_out', shape=(n_classes,), trainable=True, initializer=tf.zeros_initializer())
        outputs = tf.nn.xw_plus_b(inputs, W, b, name='dense_out')
        loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=outputs))
        pred = tf.argmax(outputs, axis=-1, name='predict', output_type=tf.int32)
        acc = tf.reduce_sum(tf.to_float(tf.equal(pred, labels))) / tf.to_float(tf.shape(inputs)[0])
        return outputs, pred, loss, acc

# %%
def cnn(inputs, labels, seq_lens, k_size, n_filters, n_classes, n_layers, n_units, dropout, l2_coef=1e-3, name='classifier', is_training=True, reuse=False):
    with tf.variable_scope(name, reuse=reuse):
        outputs = []
        mask = tf.sequence_mask(seq_lens, dtype=tf.float32)
        mask
        for ksz, nf in zip(k_size, n_filters):
            output = tf.layers.conv1d(inputs,
                                      nf, 
                                      ksz, 
                                      padding='same',
                                      kernel_initializer=tf.glorot_uniform_initializer(), 
                                      bias_initializer=tf.zeros_initializer(), 
                                      kernel_regularizer=tf.contrib.layers.l2_regularizer(scale=l2_coef))
            if is_training:
                output = tf.nn.dropout(output, 1-dropout, noise_shape=(1, 1, nf))
            output = tf.reduce_max(output, axis=1)
            outputs.append(output)
        outputs = tf.concat(outputs, axis=-1)
        for i in range(n_layers):
            W = tf.get_variable(name='W_{}'.format(i), shape=(outputs.shape[-1], n_units), trainable=True, initializer=tf.glorot_uniform_initializer(), regularizer=tf.contrib.layers.l2_regularizer(scale=l2_coef))
            b = tf.get_variable(name='b_{}'.format(i), shape=(n_units,), trainable=True, initializer=tf.zeros_initializer())
            outputs = tf.nn.xw_plus_b(outputs, W, b, name='dense_{}'.format(i))
            if is_training:
                outputs = tf.nn.dropout(outputs, keep_prob=1.0-dropout)
        W = tf.get_variable(name='W_out', shape=(outputs.shape[-1], n_classes), trainable=True, initializer=tf.glorot_uniform_initializer(), regularizer=tf.contrib.layers.l2_regularizer(scale=l2_coef))
        b = tf.get_variable(name='b_out', shape=(n_classes,), trainable=True, initializer=tf.zeros_initializer())
        outputs = tf.nn.xw_plus_b(outputs, W, b, name='dense_out')
        loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=outputs))
        pred = tf.argmax(outputs, axis=-1, name='predict', output_type=tf.int32)
        acc = tf.reduce_sum(tf.to_float(tf.equal(pred, labels))) / tf.to_float(tf.shape(inputs)[0])
        return outputs, pred, loss, acc

# %%
class2idx = {
    'fashion': 0,
    'technology': 1,
    'music': 2,
    'lifestyle': 3,
    'travel': 4
}
idx2class = {
    v: k for k, v in class2idx.items()
}
VERSION = 12
logger = get_logger('classify data/{}/logs'.format(VERSION))

# %%
def pad_sequences(sequences):
    maxlen = max(len(x) for x in sequences)
#     print(np.argmax([len(x) for x in sequences]))
    if isinstance(sequences[0], np.ndarray):
        arr = np.zeros((maxlen, len(sequences)) + sequences[0].shape[1:])
    else:
        arr = np.zeros((maxlen, len(sequences)))
#     print(arr.shape)
    for i, x in enumerate(sequences):
        arr[:len(x), i] = x
    return np.transpose(arr, axes=[1, 0] + [x for x in range(2, arr.ndim)])
def get_batch(X, y, batch_size, shuffle=True):
    assert len(X) == len(y)
    idx = np.arange(0, len(X))
    X = np.array(X)
    y = np.array([class2idx[x] for x in y])
    if shuffle:
        idx = np.random.permutation(idx)
    for i in range(0, len(idx), batch_size):
        indices = idx[i:i+batch_size]
#         print(indices)
        batch = X[indices]
        embed = pad_sequences([x[0] for x in batch])
        labels = y[indices]
        seq_len = [len(x[0]) for x in batch]
        yield embed, labels, seq_len

# %%
tf.reset_default_graph()
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
x = tf.placeholder(dtype=tf.float32, shape=(None, None, 1024, 4), name='x')
y = tf.placeholder(dtype=tf.int32, shape=(None,), name='y')
seq_len = tf.placeholder(dtype=tf.int32, shape=(None,), name='seq_len')
drop = tf.placeholder(dtype=tf.float32, shape=(), name='drop')
drop_e = tf.placeholder(dtype=tf.float32, shape=(), name='drop_e')
elmo, elmo_l2_reg = elmo_embedding(x, seq_lens=seq_len, l2_coef=1e-3, layer_norm=True)
shape = tf.shape(elmo)
elmo = tf.nn.dropout(elmo, 1-drop_e, noise_shape=(shape[0], shape[1], 1)) * (1-drop_e)
outputs, pred, loss, acc = cnn(elmo, y, seq_len, (3, 4, 5), (128, 128, 128), 5, 2, 256, drop, 1e-3, name='classifier')
optimizer = tf.train.AdamOptimizer(1e-3)
grads, _vars = zip(*optimizer.compute_gradients(loss + elmo_l2_reg + tf.losses.get_regularization_loss()))
grads, _ = tf.clip_by_global_norm(grads, clip_norm=1.0)
global_step = tf.Variable(0, name="global_step", trainable=False)
train_op = optimizer.apply_gradients(
    zip(grads, _vars),
    global_step=global_step
)
session.run(tf.global_variables_initializer())

# %%
with open('classify data/X_train.pkl', 'rb') as inp:
    X_train = pickle.load(inp)
with open('classify data/y_train.pkl', 'rb') as inp:
    y_train = pickle.load(inp)
with open('classify data/X_test.pkl', 'rb') as inp:
    X_test = pickle.load(inp)
with open('classify data/y_test.pkl', 'rb') as inp:
    y_test = pickle.load(inp)
with open('classify data/X_val.pkl', 'rb') as inp:
    X_val = pickle.load(inp)
with open('classify data/y_val.pkl', 'rb') as inp:
    y_val = pickle.load(inp)

# %%
saver = tf.train.Saver(tf.global_variables(), max_to_keep=1000)

# %%
prob = tf.nn.softmax(outputs, axis=-1)

# %%
for _ in range(20):
    gen = get_batch(X_train, y_train, 32)
    for e, l, sl in gen:
        _, s, l, a = session.run([train_op, global_step, loss, acc], feed_dict={
            x: e, y: l, seq_len: sl, drop: 0.5, drop_e: 0.3
        })
        logger.info('Step {}: loss {}, acc {}'.format(s, l, a))
    gen = get_batch(X_val, y_val, 32, shuffle=False)
    saver.save(session, 'classify data/{}/classifier.cpkt'.format(VERSION), global_step=s)
    total_loss = 0.0
    total_acc = 0.0
    count = 0
    for e, l, sl in gen:
        l, a = session.run([loss, acc], feed_dict={
            x: e, y: l, seq_len: sl, drop: 0.0, drop_e: 0.0
        })
        logger.info('Evaluation: loss {}, acc {}'.format(l, a))
        total_loss += l * len(e)
        total_acc += a * len(e)
        count += len(e)
    logger.info('Evaluation: total loss {}, total acc {}'.format(total_loss / count, total_acc / count))
# Out:
# Step 1: loss 8.368650436401367, acc 0.21875
# Step 2: loss 10.25060749053955, acc 0.34375
# Step 3: loss 11.906867980957031, acc 0.21875
# Step 4: loss 8.783586502075195, acc 0.3125
# Step 5: loss 10.477054595947266, acc 0.15625
# Step 6: loss 8.430365562438965, acc 0.1875
# Step 7: loss 10.568829536437988, acc 0.15625
# Step 8: loss 12.06379508972168, acc 0.25
# Step 9: loss 7.990574836730957, acc 0.28125
# Step 10: loss 8.672176361083984, acc 0.3125
# Step 11: loss 6.602428436279297, acc 0.28125
# Step 12: loss 5.82124662399292, acc 0.3125
# Step 13: loss 5.628190994262695, acc 0.28125
# Step 14: loss 5.920144081115723, acc 0.34375
# Step 15: loss 8.235280990600586, acc 0.40625
# Step 16: loss 8.71013355255127, acc 0.125
# Step 17: loss 8.240959167480469, acc 0.375
# Step 18: loss 10.240030288696289, acc 0.375
# Step 19: loss 9.54597282409668, acc 0.375
# Step 20: loss 6.971106052398682, acc 0.28125
# Step 21: loss 4.875779628753662, acc 0.5625
# Step 22: loss 10.827559471130371, acc 0.34375
# Step 23: loss 6.370181560516357, acc 0.34375
# Step 24: loss 8.67503547668457, acc 0.3125
# Step 25: loss 5.923070907592773, acc 0.53125
# Step 26: loss 5.519527435302734, acc 0.46875
# Step 27: loss 4.517037391662598, acc 0.5
# Step 28: loss 6.02199649810791, acc 0.3125
# Step 29: loss 5.425725936889648, acc 0.4375
# Step 30: loss 3.4565486907958984, acc 0.5625
# Step 31: loss 5.041460037231445, acc 0.5
# Step 32: loss 7.00505256652832, acc 0.34375
# Step 33: loss 4.980367660522461, acc 0.40625
# Step 34: loss 5.935802936553955, acc 0.3125
# Step 35: loss 4.48049259185791, acc 0.46875
# Step 36: loss 6.353817939758301, acc 0.375
# Step 37: loss 5.712916374206543, acc 0.34375
# Step 38: loss 6.402693748474121, acc 0.4375
# Step 39: loss 5.154073715209961, acc 0.34375
# Step 40: loss 7.603442192077637, acc 0.375
# Step 41: loss 4.288077354431152, acc 0.5625
# Step 42: loss 5.990792274475098, acc 0.40625
# Step 43: loss 3.6180052757263184, acc 0.4375
# Step 44: loss 6.184727191925049, acc 0.375
# Evaluation: loss 0.22918900847434998, acc 0.90625
# Evaluation: loss 0.27177196741104126, acc 0.96875
# Evaluation: loss 0.22984221577644348, acc 0.875
# Evaluation: loss 0.07510650157928467, acc 0.96875
# Evaluation: loss 0.40527135133743286, acc 0.875
# Evaluation: loss 0.23900717496871948, acc 0.9375
# Evaluation: loss 0.240158349275589, acc 0.9375
# Evaluation: loss 0.053073082119226456, acc 0.96875
# Evaluation: loss 0.20245900750160217, acc 0.90625
# Evaluation: loss 0.09582555294036865, acc 0.96875
# Evaluation: loss 0.10830417275428772, acc 0.9375
# Evaluation: loss 0.26381823420524597, acc 0.9375
# Evaluation: loss 0.17546606063842773, acc 0.9375
# Evaluation: loss 0.027084123343229294, acc 1.0
# Evaluation: loss 0.1695772111415863, acc 0.9333333373069763
# Evaluation: total loss 0.15901503417912113, total acc 0.9514687101655231

# %%
saver.restore(session, 'classify data/12/classifier.cpkt-3822')
# Out:
# INFO:tensorflow:Restoring parameters from classify data/12/classifier.cpkt-3822
# Restoring parameters from classify data/12/classifier.cpkt-3822

# %%
gen = get_batch(X_test, y_test, 32, shuffle=False)
all_pred = []
all_prob = []
total_loss = 0.0
total_acc = 0.0
count = 0
for e, lb, sl in gen:
    pr, p, l, a = session.run([prob, pred, loss, acc], feed_dict={
        x: e, y: lb, seq_len: sl, drop: 0.0, drop_e: 0.0
    })
    print('Evaluation: loss {}, acc {}'.format(l, a))
    total_loss += l * len(e)
    total_acc += a * len(e)
    count += len(e)
    all_pred.extend(p)
    all_prob.extend(pr)
print('Evaluation: total loss {}, total acc {}'.format(total_loss / count, total_acc / count))
# Out:
# Evaluation: loss 0.2792838513851166, acc 0.9375
# Evaluation: loss 0.4210464656352997, acc 0.90625
# Evaluation: loss 0.12554848194122314, acc 0.96875
# Evaluation: loss 0.003417950589209795, acc 1.0
# Evaluation: loss 0.31914669275283813, acc 0.9375
# Evaluation: loss 0.3984847664833069, acc 0.9375
# Evaluation: loss 0.1848779171705246, acc 0.9375
# Evaluation: loss 0.15837159752845764, acc 0.9375
# Evaluation: loss 0.19729937613010406, acc 0.9375
# Evaluation: loss 0.5918911695480347, acc 0.875
# Evaluation: loss 0.19225803017616272, acc 0.96875
# Evaluation: loss 0.5521550178527832, acc 0.9375
# Evaluation: loss 0.32669249176979065, acc 0.9375
# Evaluation: loss 0.021329544484615326, acc 1.0
# Evaluation: loss 0.06677235662937164, acc 0.96875
# Evaluation: loss 0.2697557210922241, acc 0.9375
# Evaluation: loss 0.25986945629119873, acc 0.90625
# Evaluation: loss 0.06645567715167999, acc 0.96875
# Evaluation: loss 0.005481920205056667, acc 1.0
# Evaluation: loss 0.6838467717170715, acc 0.875
# Evaluation: loss 0.022232165560126305, acc 1.0
# Evaluation: loss 0.1123342514038086, acc 0.96875
# Evaluation: loss 0.6708186268806458, acc 0.9375
# Evaluation: loss 0.24196065962314606, acc 0.9375
# Evaluation: loss 0.3425626754760742, acc 0.90625
# Evaluation: loss 0.017882313579320908, acc 1.0
# Evaluation: loss 0.07436962425708771, acc 0.96875
# Evaluation: loss 0.05059022828936577, acc 1.0
# Evaluation: loss 0.0933169573545456, acc 0.96875
# Evaluation: loss 0.1757286638021469, acc 0.9375
# Evaluation: loss 0.27717989683151245, acc 0.9375
# Evaluation: loss 0.8000017404556274, acc 0.90625
# Evaluation: loss 0.20545744895935059, acc 0.96875
# Evaluation: loss 0.009797058999538422, acc 1.0
# Evaluation: loss 0.022102970629930496, acc 1.0
# Evaluation: loss 0.5420535802841187, acc 0.90625
# Evaluation: loss 0.12092524021863937, acc 0.9375
# Evaluation: loss 0.13756412267684937, acc 0.9375
# Evaluation: loss 0.0608237162232399, acc 0.96875
# Evaluation: loss 0.35307183861732483, acc 0.90625
# Evaluation: loss 0.02962520532310009, acc 1.0
# Evaluation: loss 0.006949381437152624, acc 1.0
# Evaluation: loss 0.3674704134464264, acc 0.9375
# Evaluation: loss 0.06853604316711426, acc 0.96875
# Evaluation: loss 0.1807423233985901, acc 0.9375
# Evaluation: loss 0.1591220200061798, acc 0.90625
# Evaluation: loss 0.23975008726119995, acc 0.9375
# Evaluation: loss 0.24776242673397064, acc 0.9375
# Evaluation: loss 0.18575513362884521, acc 0.9375
# Evaluation: loss 0.2845951020717621, acc 0.9375
# Evaluation: loss 0.059233684092760086, acc 0.96875
# Evaluation: loss 0.046348437666893005, acc 1.0
# Evaluation: loss 0.7051723003387451, acc 0.90625
# Evaluation: loss 0.06996089965105057, acc 0.96875
# Evaluation: loss 0.143157958984375, acc 0.96875
# Evaluation: loss 0.0007331798551604152, acc 1.0
# Evaluation: loss 0.09547776728868484, acc 0.96875
# Evaluation: loss 0.16796521842479706, acc 0.96875
# Evaluation: loss 0.12717202305793762, acc 0.9375
# Evaluation: loss 0.06314370781183243, acc 0.96875
# Evaluation: loss 0.07920156419277191, acc 0.96875
# Evaluation: loss 0.2953718900680542, acc 0.90625
# Evaluation: loss 0.05110015347599983, acc 0.96875
# Evaluation: loss 0.09483659267425537, acc 0.9375
# Evaluation: loss 0.005002170335501432, acc 1.0
# Evaluation: total loss 0.18643957397549132, total acc 0.9550102249488752

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(classification_report(y_true=y_test, y_pred=[idx2class[c] for c in all_pred]))
# Out:
#              precision    recall  f1-score   support
#
#     fashion       0.97      0.93      0.95       583
#   lifestyle       0.96      0.95      0.95       981
#       music       0.96      0.93      0.94       597
#  technology       0.95      0.98      0.97      1029
#      travel       0.94      0.97      0.95       722
#
# avg / total       0.96      0.96      0.95      3912

# %%
count = 0
for yp, yt, (_, mess), pr in zip(all_pred, y_test, X_test, all_prob):
    yp = idx2class[yp]
    if yp != yt:
        count += 1
        print('True:', yt)
        print('Pred:', yp)
        print('Prob:', {c: p for c, p in zip(class2idx.keys(), pr)})
        print(mess)
        print('-' * 80)
print('Total:', count)
# Out:
# True: travel
# Pred: technology
# Prob: {'fashion': 6.3692255e-07, 'technology': 0.9964719, 'music': 4.807285e-07, 'lifestyle': 7.049488e-06, 'travel': 0.0035201053}
# Nếu bạn thích chinh phục những cung đường mạo hiểm thì đây chính là gói bảo hiểm dành cho bạn. Bảo hiểm FWD đang tặng MIỄN PHÍ 100,000 gói bảo hiểm tai nạn cá nhân, bảo hiểm đến 300 TRIỆU ĐỒNG. Nhanh tay đăng ký và nhận ngay gói bảo hiểm chỉ trong vòng 3 phút tại: https://tiki.vn/top/fwd
# #FWDbảohiểm #Sốngđầytừhômnay
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# Prob: {'fashion': 0.0035031168, 'technology': 0.18375571, 'music': 0.6855716, 'lifestyle': 0.086963035, 'travel': 0.040206585}
# Album được sưu tập từ FB bạn Huyền Phạm (https://www.facebook.com/HuyenCherry93) và FB Món Ngon Hà Nội (https://www.facebook.com/HNmonngon)
#
# ALBUM vẫn còn đang cập nhật tiếp. Ôi nhiều món quá update không xuể được ạ.
#
# #Nhim
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 9.605537e-05, 'technology': 0.99631494, 'music': 0.0024031543, 'lifestyle': 1.5168294e-05, 'travel': 0.0011707041}
# [Xin phép Ad cho PR 1 chút ạ :3] Trang chuyên dịch tin US - UK, Kbiz từ các trang chính thống^^ Ngoài ra còn có các clip về đồ ăn, phim ảnh, phương pháp học tiếng Anh, Hàn và nhiều thông tin khác ^3^ Mong mọi người ủng hộ page nha ❤ #Kpop #Kbiz #USUK
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Prob: {'fashion': 0.0017953535, 'technology': 0.99730504, 'music': 2.7781185e-05, 'lifestyle': 0.00042032058, 'travel': 0.00045153845}
# Chào các bạn, tôi đang tìm học sinh để dạy kèm tiếng anh với giá rẻ, với kinh nghiệm giảng dạy của tôi hứa sẽ sớm mang đến cho bạn kết quả tốt và nhanh nhất. xin vui lòng liên hệ với tôi qua số điện thoại : 0985446704 (Nash)
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# Prob: {'fashion': 0.0026724606, 'technology': 0.0012300771, 'music': 0.59473765, 'lifestyle': 0.3661897, 'travel': 0.03517016}
# Lẽ giản đơn
#
# đã bao giờ em bóc lịch
# thấy qua vô nghĩa một ngày
# rồi em ghi vào nhật ký:
# …ngày mai như ngày hôm nay…
# đã bao giờ em hoảng hốt
# khi mình bất lực trước mình
# và em thấy trong đôi mắt
# có gì ứa ra
# vô hình
# nếu có xin em đừng sợ
# thật ra là rất bình thường
# tất cả chúng ta đều thế
# mỗi khi cần được yêu thương
#
# - Nguyễn Thế Hoàng Linh
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Prob: {'fashion': 0.043791227, 'technology': 0.7744502, 'music': 0.09952025, 'lifestyle': 0.049122673, 'travel': 0.033115666}
# Lời nói chỉ là sáo rỗng, cách làm và kết quả mới là điều quan trọng
# Giá trị đó có ai hiểu thấu .🐒!?
#
# https://www.facebook.com/groups/536260456747103/?multi_permalinks=537760159930466&notif_id=1515642911336722&notif_t=group_activity
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Prob: {'fashion': 0.001987336, 'technology': 0.00081373577, 'music': 0.7790322, 'lifestyle': 0.00090358226, 'travel': 0.21726315}
# Còn 20 ngày nữa là chúng ta được gặp 24 con người tài giỏi, dễ thương này ở tập đầu tiên rùi đấy cả nhà ạ. Cùng đếm ngược với Ad nào!!!
#
# Art Director: Cu-tie
# Photographer: Tee Lee
# Makeup: Maybelline NewYork
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 6.641593e-05, 'technology': 0.9050959, 'music': 0.030064734, 'lifestyle': 1.4121253e-05, 'travel': 0.06475874}
# Xin phép ad cho bọn mình PR một chút ạ! :)
# Dành cho những ai yêu thích chương trình Eurovision, tụi mình mới lập page nhằm tạo ra một nơi để các bạn có thể vào bàn tán hay cập nhật tin tức từ chương trình ạ! :)
# Các bạn like page nhé! :D
# https://www.facebook.com/H%E1%BB%99i-nh%E1%BB%AFng-ng%C6%B0%E1%BB%9Di-th%C3%ADch-xem-Eurovision-1865101713747896/
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# Prob: {'fashion': 0.0036705972, 'technology': 0.032651678, 'music': 0.85912436, 'lifestyle': 0.0006953457, 'travel': 0.10385798}
# Kết Quả Giveaway nhân dịp page đạt 140k follow.
#
# Lúc mà Hannah tổng hợp danh sách xong là nhìn lại thấy follow đã gần 150k rồi, thật sự cám ơn các bạn đã yêu quý Na. Chắc phải chuẩn bị giveaway mới luôn quá :P
#
# Chúc mừng bạn Trần Hoài Thu đã là người may mắn, bạn inbox cho Hannah thông tin gửi quà nhé!
#
# Love,
# Hannah
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Prob: {'fashion': 0.049258187, 'technology': 0.9427203, 'music': 6.518632e-05, 'lifestyle': 0.00065542926, 'travel': 0.0073009757}
# "sau một tháng mở cửa Expo 2012, Nhà triển lãm Việt Nam là một trong những nhà triển lãm thu hút đông khách tham quan nhờ không gian trưng bày thân thiện và chương trình biểu diễn nghệ thuật độc đáo, hấp dẫn. "
#
# Ôi chúa tôi, nó vít cái bài này như kiểu VN không có ai lết xác đến được cái triển lãm để biết cái sảnh đường của VN nó nhàm chán và xấu và vắng hiu hắt đến như thế nào ấy?
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.011645619, 'technology': 0.010725444, 'music': 0.008425397, 'lifestyle': 0.9649379, 'travel': 0.00426569}
# "Trong tình cảm, Tiên từng là người đầy rẫy lỗi lầm trong quá khứ nhưng Tiên tự hào về điều đó. Vì có những lỗi lầm đó, mình mới có ngày hôm nay và biết quý trọng những điều chân thành mà tình yêu đem lại."
# - Tiên Tiên -
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Prob: {'fashion': 0.6627299, 'technology': 0.0019267438, 'music': 5.7335674e-05, 'lifestyle': 0.3352438, 'travel': 4.2235897e-05}
# Bên cạnh những bộ cánh tinh xảo, những người đẹp không thể tỏa sáng trên sự kiện thảm đỏ nếu thiếu đi lớp trang điểm và tạo kiểu tóc phù hợp. Khi chủ đề được chọn năm nay là tôn giáo, nó đã mở ra một cơ hội mới  cho các ngôi sao và ekip của mình thỏa sức sáng tạo trong bầu trời nghệ thuật đầy chất thơ.
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.0024143043, 'technology': 0.029095462, 'music': 0.16060506, 'lifestyle': 0.8009842, 'travel': 0.006900968}
# “Ngoài gia đình chúng ta ra, còn lại, đừng vội dốc lòng tin tưởng và quá đặt niềm hy vọng vào ai. Bởi chẳn ai đủ nhiều yêu thương và đủ nhiều cảm thông dành cho một người xa lạ.”
#
# (Ảnh: @piiaen)
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.0002453236, 'technology': 0.016914379, 'music': 2.2229044e-05, 'lifestyle': 0.052950688, 'travel': 0.9298674}
# Thường thì những người đã tu thiền ( hoặc tu một pháp môn nào đó) và đã nói là phi lợi nhuận thì sao Thầy lại thu tiền. Thầy phát tâm đi, ko lợi nhuân, ko thu tiền, phát tâm cho mọi người cùng tập theo Thầy, vì lợi ích chúng sinh đi!
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Prob: {'fashion': 0.060035508, 'technology': 0.0051390897, 'music': 0.34883824, 'lifestyle': 0.5712638, 'travel': 0.014723409}
# MC: -Và sau đây là một nhân vật chuẩn mực về đạo đức, cả ngoài đời lẫn trên sân cỏ cũng như trên sân bóng, blah blah... Lương Xuân Trường
# Fans: -Yaaayyyy 👏👏👏
# Trường (ngơ ngác): - Đang nói ai í nhỉ?
# - Anh đấy
# - Ơ... :v
#
# Trời ơi, coi thấy dễ thương gì đâu, ai fan Trường híp điểm danh nào :)))
# Video: Bình An
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.13165434, 'technology': 9.3931526e-08, 'music': 4.5523666e-06, 'lifestyle': 0.8683401, 'travel': 9.592325e-07}
# Quang Hùng và Mâu Thuỷ cùng nhau có mặt tại đề cử người mẫu xuất sắc của tạp chí thời trang Elle. Đây là một niềm vui và tự hào của gia đình beU
# Hãy bình chọn cho Hùng và Thuỷ để cổ vũ tinh thần cho họ trong sự nghiệp người mẫu này mọi người nhé!
# #MauThuy #QuangHung #beUModels #ElleStyleAwards
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 0.0001052986, 'technology': 0.9392222, 'music': 0.0001816969, 'lifestyle': 1.2723638e-05, 'travel': 0.06047817}
# Xin phép ad nhé. Mình đang tham dự cuộc thi này... Mọi người like và share giùm mình nhé. Thanks nhiều
#
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/709
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/708
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/707
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/706
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/705
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Prob: {'fashion': 0.003886742, 'technology': 0.020514537, 'music': 0.7345164, 'lifestyle': 0.0014968727, 'travel': 0.23958547}
# Hi there,
# I really like your posts as they motivate me to do my job still better. I have noticed that you work with images very often. Im photographer & CEO of energepic.com - you can get there plenty licensed FREE photos of any category, hope it will be useful for your future projects even they're now perfect!
#
# Have a great & succesful day!
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Prob: {'fashion': 0.0122765275, 'technology': 0.3767929, 'music': 0.092970565, 'lifestyle': 0.012131482, 'travel': 0.50582856}
# Những từ còn thiếu quá dễ với bạn đúng hok hãy truy cập vào facebook Katy Perry Vietnam để tham gia trả lời câu hỏi và nhận được bộ CD + DVD Last Friday Night (Deluxe Single). Có tới 3 phần quà cho 3 bạn may mắn lên nhá !!!
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 2.793828e-06, 'technology': 5.1270877e-08, 'music': 1.2323872e-08, 'lifestyle': 0.017240409, 'travel': 0.98275673}
# Nhiều người nghĩ là đi du lịch thì khó mặc đẹp, vì phải mang nhiều đồ lỉnh kỉnh, lại phải di chuyển nhiều, rồi khó ủi đồ, vv...nhưng thật ra lúc đi du lịch mình vẫn có thể đẹp lồng lộn mà vẫn thoải mái. Có ai muốn biết bí kíp để mặc đẹp khi du lịch không? Na sẽ viết post chia sẻ nhé.
#
# PS. Hình Na tự chụp đó :)
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.00045341314, 'technology': 0.08619343, 'music': 0.0066661625, 'lifestyle': 0.9061339, 'travel': 0.0005531122}
# #FNC công ty chủ quản #FTISLAND #Minhwan xác nhận cậu và bạn đời #Yulhee đã chính thức đăng kí kết hôn hợp pháp và tiến tới kết hôn vào 19/10 năm nay
#
# Được biết Yulhee đã mang thai. Cặp đôi xác nhận mối quan hệ vào năm ngoái 2017
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 4.383439e-06, 'technology': 0.9999409, 'music': 2.8915967e-05, 'lifestyle': 2.3011471e-05, 'travel': 2.7771362e-06}
# Chị em kế toán có gặp khó khăn với Excel không?
# Làm báo cáo có bao giờ bị lỗi mà chẳng biết lỗi ở đâu không?
# Hay là đọc đề bài tập Excel mà đọc tiếng Uzbekistan?
#
# Nếu còn nhiều thắc mắc liên quan đến Excel thì phải tham gia ngay Nhóm Thủ thuật Excel để được 10000 anh em cao thủ văn phòng hỗ trợ kịp thời nhé! Tham gia ngay thôi!
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 0.0027001353, 'technology': 0.40392023, 'music': 0.0011385761, 'lifestyle': 0.28600612, 'travel': 0.30623496}
# Mình đang định mời 1 thầy giáo tiếng Anh người Anh dạy thêm Tiếng Anh giao tiếp vào 1-2 buổi tối ở Cầu Giấy. Mình cần 4 bạn nữa để mở 1 lớp học cùng mình... Bạn nào có nhu cầu liên lạc vs mình nhé - 0947014591
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.044527564, 'technology': 0.09276975, 'music': 1.4412105e-06, 'lifestyle': 0.00018246222, 'travel': 0.86251885}
# Mình chỉ để đây và không nói gì thêm nữa? ❤️❤️❤️
#
# 🔖 Follow 𝓘𝓷𝓼𝓽𝓪𝓰𝓻𝓪𝓶 để cập nhật những hình ảnh độc nhất chỉ có tại www.instagram.com/theface.vietnam.official
#
# #TheFace #TheFaceVietnam #TheFaceVietnam2018 #TFVN2018 #TFVN
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 1.6862413e-07, 'technology': 5.2620845e-07, 'music': 4.850055e-05, 'lifestyle': 0.00083842804, 'travel': 0.9991123}
# Hello các cô gái, bà Na đang đi du lịch nên mấy hôm tới sẽ ko viết bài mà sẽ chăm khoe hình thôi nha. Về đến nơi sẽ chăm chỉ phục vụ chị em trở lại nhaaa.
#
# P.S Na đang đứng trước bảo tàng Louvre ở Paris đó :)
#
# Love,
# Hannah
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.13251942, 'technology': 0.00010406045, 'music': 2.2975186e-05, 'lifestyle': 0.8672665, 'travel': 8.716993e-05}
# Bạn thuộc cung hoàng đạo nào? Đâu là phong cách makeup hợp với cung hoàng đạo của bạn?
# Cùng tô điểm cho "cửa sổ tâm hồn" thật nổi bật, thu hút và phù hợp với cung hoàng đạo của chính mình nhé!
# https://www.elle.vn/xu-huong-lam-dep/mau-chi-ke-mat-cung-hoang-dao
# #beUmodels #beUmgmt #makeup #fashion #eyes
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Prob: {'fashion': 0.003064231, 'technology': 0.10472903, 'music': 0.88401645, 'lifestyle': 0.00048493972, 'travel': 0.0077052973}
# http://giaitri.vnexpress.net/tin-tuc/thoi-trang/lang-mot/hoang-minh-ha-toi-ung-ho-cac-nha-thiet-ke-dong-tinh-2993656.html
#
# Trong đây có đoạn nói HMH không còn là bạn trai của HL đừng có nhắc bạn gái hoài để bị hiểu lầm nha ad
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.0017874761, 'technology': 0.0016722643, 'music': 4.1678754e-06, 'lifestyle': 0.060660157, 'travel': 0.93587595}
# Vé thưởng cho 5 bạn đọc được công bố đã có ! Mời các bạn đến văn phòng Elle Vietnam 111B Lý Chính Thắng P.7 Q.3 để nhận vé ! Khi đi các bạn nhớ đem theo chứng minh nhân dân để đối chiếu nhé ! Hẹn gặp lại các bạn !
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.03511993, 'technology': 0.23371568, 'music': 0.20724374, 'lifestyle': 0.0025215663, 'travel': 0.5213991}
# Designer JOE CHIA showcased a very Black & Bold Collection at VIFW FALL WINTER 2016. According to the designer, a very special and exclusive collaboration Reebok X Crossover X JOE CHIA is coming up soon! Geometrical lines on the side - as elusive as a phantom
#
# @reebokclassics @reebokmalaysia @crossoverconceptstore @joechia  #ReebokxCrossover #TSOPbyJoeChia #instapumpfury #thisISclassic #JoeChia
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 0.009813836, 'technology': 0.95696515, 'music': 0.018554322, 'lifestyle': 0.0006853435, 'travel': 0.013981321}
# Xin chào các bạn 😊 Đây là Fanpage CFS của Produce101SS2 💖 Các bạn hãy gửi những tâm tư, tình cảm hay những suy nghĩ của bạn về Produce 101 SS2 hoặc về các bias của mình nhé 💕https://www.facebook.com/cip101ss2vnfptn/?hc_location=ufi
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Prob: {'fashion': 0.52884495, 'technology': 1.8654914e-06, 'music': 2.832559e-06, 'lifestyle': 0.47113904, 'travel': 1.1348089e-05}
# ELLE MAN PARTY
# Toàn bộ hình ảnh của buổi tiệc ra mắt ELLE MAN tại Chill Skybar & Lounge tối qua!
#
# Hãy click vào link bên dưới để xem những hình ảnh của Hoa hậu Thùy Dung, Mai Phương Thúy, người mẫu Hoàng Thùy, Trà My, Thùy Trang, cùng nữ diễn viên Kathy Uyên, Hải Yến tại buổi tiệc!
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Prob: {'fashion': 0.12279541, 'technology': 0.020816047, 'music': 0.853466, 'lifestyle': 0.0025097188, 'travel': 0.00041280163}
# [ỨNG DỤNG XEM TẤT CẢ CÁC GAMESHOW TRUYỀN HÌNH TRÊN MOBILE]
# - Ai Là Triệu Phú, Đấu trường 100, Trò Chơi Âm Nhạc, Project Runway, Giọng Hát Việt Nhí 2014, Nhân tố bí ẩn XFactor, Vietnam Idol, Đừng Để Tiền Rơi,...
# Tải ứng dụng tại địa chỉ:
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# Prob: {'fashion': 0.3413344, 'technology': 0.15853435, 'music': 0.37583452, 'lifestyle': 0.11351086, 'travel': 0.010785778}
# Hình ảnh: Mark Cant
# Chỉ đạo mỹ thuật & Stylist: Steven Doan từ Wilhelmina One
# Trang điểm: Lan Nguyen Grealis sử dụng MAC
# Làm tóc: Bjorn Krischker từ Frank Agency
# Hoa tươi: Amaris Flower
# Người mẫu: Hoàng Thùy từ PRM Models Management
# Trân trọng cảm ơn John Bruce từ PRM Models đã hỗ trợ chúng tôi thực hiện hình ảnh.
# --------------------------------------------------------------------------------
# True: technology
# Pred: fashion
# Prob: {'fashion': 0.9650307, 'technology': 0.0031174857, 'music': 7.121257e-05, 'lifestyle': 0.030877301, 'travel': 0.0009032576}
# Có một nữ sinh Huế - xinh đẹp, nấu ăn ngon, violon hay, học giỏi, đảm đang, lại là mẫu áo dài Festival Huế 2018 vừa rồi. Câu chuyện ảnh được thành viên Hiếu Trương kể lại bằng ảnh.
#
# #Tinhte #cameratinhte #nusinh
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.00025661333, 'technology': 0.00040114272, 'music': 0.0007638433, 'lifestyle': 0.98525673, 'travel': 0.0133217275}
# Người nên đến thì sẽ đến, người muốn đi thì đừng nên níu kéo. Đừng ép người, đừng ép mình, đừng bận tâm đau lòng chỉ vì một chuyện, trên đời nên học cách" tùy duyên". Ai không tốt, không nên tiếc.
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 2.4100166e-07, 'technology': 0.9970408, 'music': 0.002872477, 'lifestyle': 4.5113153e-05, 'travel': 4.1386353e-05}
# Đlq nhưng phiên bản mở rộng của Global Warming của con Pit sẽ được ra mắt vào 25/11 năm nay bổ sung 1 số bài mới trong đó có Timber feat Flop-sa.
#
# Cover chính thức nhé, cứ tựa tựa như mụ Nicki với cái Era Pink Friday 8-}
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Prob: {'fashion': 0.0034879067, 'technology': 0.0018409299, 'music': 0.0049596247, 'lifestyle': 0.9565263, 'travel': 0.033185393}
# "Ai cũng có tuổi thơ
# Ai cũng có ngày xưa"
#
# Bạn đã sống bao lâu rồi? Tuổi thơ của bạn trôi qua như thế nào?  Bạn có kỉ niệm gì với những món quà vặt dưới đây?
# Hãy chia sẻ với  #BìnhBình nhé !  ^_^
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Prob: {'fashion': 8.331042e-05, 'technology': 0.048041694, 'music': 0.04127187, 'lifestyle': 0.00032394766, 'travel': 0.9102792}
# "Muốn đi được xa, hãy đi cùng nhau..." <3
#
# ---------------------
# Cám ơn bạn có facebook Phạm Hồng Thu đã viết và gửi hình tặng page <3
# Page hy vọng sẽ tiếp tục nhận được những bức hình với những câu ý nghĩa như thế này từ các bạn :*
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Prob: {'fashion': 1.0, 'technology': 2.5320906e-10, 'music': 4.858038e-12, 'lifestyle': 1.7156871e-08, 'travel': 1.4835041e-12}
# Không chỉ là những thước vải lụa là, mà phong cách trang điểm cũng được nhà thiết kế Nguyễn Công Trí chú trọng để tạo nên tổng thể thống nhất và ấn tượng trong show diễn mở màng Vietnam International Fashion Week đêm qua.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.0002965546, 'technology': 0.78580284, 'music': 0.000114746304, 'lifestyle': 0.20026743, 'travel': 0.013518409}
# Khoe các combo LANIEGE Na tậu dc.
#
# Link mua hàng trên website đây nha mọi người:  http://bit.ly/LaneigeExclusiveDeal
#
# Bạn nào không mua được trên website thì có thể đăng ký để mua ở đây nha: https://goo.gl/forms/5sejSUZUo1bn5Irt2. Nhưng Na khuyên là mua trên website sẽ chắc ăn hơn về mặt hàng hoá và nhanh hơn là đăng ký theo link này đó nhé.
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.0023693333, 'technology': 0.0073856306, 'music': 0.00045870515, 'lifestyle': 0.0034184628, 'travel': 0.9863679}
# Hôm qua những bạn đến Casting Call tại Crescent Mall đừng bỏ lỡ cơ hội giảm 20% học phí nhé!!!
# Gửi ảnh về page beU Academy để nhận voucher ngay nhé!!!
# Lưu ý Ảnh bài post FB phải có #CrescentMall và check in tại đây nhé các bạn!!!
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 0.00027736285, 'technology': 0.17758407, 'music': 0.0006408037, 'lifestyle': 0.00031175348, 'travel': 0.821186}
# 500 a e cho hỏi ở đâu hà nội mua 7+ uy tín và giá hợp lý ạ ( e muốn mua máy mới 100%)
# Với giá 18 củ đổ lại thì giờ e nên mua gì hợp lý ạ
# e thấy ở FPT và Phúc anh chênh nhau 2 củ ạ
# Rất mong ae tư vấn giúp e ạ
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.08114905, 'technology': 0.25907764, 'music': 0.022328421, 'lifestyle': 0.07123513, 'travel': 0.5662098}
# CÁCH MẪU NAIL ĐẸP NHẤT 2017!
# 20/10 #phongcachsong gửi tặng hội chị em những mẫu nail sang choảng dễ làm để diện nha!
# Lưu vào để dùng dần!!!
# https://www.facebook.com/permalink.php?story_fbid=1532765190137703&id=338271296253771&pnref=story
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Prob: {'fashion': 0.0019091347, 'technology': 0.46794575, 'music': 0.41800198, 'lifestyle': 0.0008865208, 'travel': 0.11125653}
# Chuong trinh oi. That la sai lam thi chuong trinh loai mot tiem nang rat lon. BGK khong the dua vao thi sinh muon loai ai trong do.i de loai nguoi do trong khi Ba Tung gioi hon rat nhieu so voi 2 ban con lai. Doc xong bai phong van khong thich Gia Khang.
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 0.050083347, 'technology': 0.12223221, 'music': 3.6305362e-05, 'lifestyle': 0.0050478824, 'travel': 0.8226003}
# “Làm startup cũng giống như đi tàu lượn siêu tốc. Lúc nó chậm thì kinh hãi. Lúc nó nhanh mình vừa thích, lại vừa run”. Hành trình khởi nghiệp là hành trình của những thử thách mà thú vị cô cùng, nhưng chắc chắn đó không bao giờ là con đường trải đầy hoa hồng...
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Prob: {'fashion': 0.009826248, 'technology': 0.004674931, 'music': 0.054286048, 'lifestyle': 0.8752199, 'travel': 0.055992797}
# 💋 💋BỐT NỮ 💋 💋
# 😍😍😍SIÊU CHẤT HOT NHẤT 2017😍😍😍
# SALE CỰC PHÊ #SALE_OFF_UP_TO_40%
# CHỈ TỪ 280K - 300K
# 👉 BỐT NỮ đẹp- sịn - form chuẩn
# 👉 #Nhìn_MUỐN_MUA_NGAY
# 👉 #HÀNG_NGOÀI_ĐẸP_HƠN_ẢNH
# ⚠ #BỐT_HOT hết liên tục, số lượng #siêu_có_hạn, chậm chân xin đừng nuối tiếc 💋 💋
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Prob: {'fashion': 0.003916876, 'technology': 0.00015321287, 'music': 9.194026e-06, 'lifestyle': 0.9686525, 'travel': 0.02726818}
# Manila thật biết cách lấy lòng người, dù chân đã đặt tới nhiều vùng đất khác nhau nhưng chúng tôi vẫn thấy choáng ngợp và ngỡ ngàng trước vẻ đẹp của nó. Những giá trị lịch sử và văn hoá còn lưu giữ khiến Manila dù đã trở thành một quý cô sành điệu thời hiện đại vẫn vẹn nguyên một bản sắc rất riêng.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.0031529246, 'technology': 0.10216079, 'music': 0.00010150904, 'lifestyle': 0.19334128, 'travel': 0.7012435}
# Mọi người biết Na đang làm gì không? Na dành nguyên ngày thứ 7 của mình để lựa đồ skincare không dùng tới rồi chụp hình để chuẩn bị làm giveaway cho mọi người đó. Hôm qua nói là soạn đồ dùng rồi, nhưng hôm nay check mới biết là có nhiều set chưa khui nên tặng đồ mới luôn. Mọi người đặt gạch chờ nhaaa.
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Prob: {'fashion': 0.00094071164, 'technology': 0.0064287377, 'music': 0.20384687, 'lifestyle': 0.00162808, 'travel': 0.7871556}
# VEVO
# We're aware of the shady activity happening now with our channels on YouTube. The videos have not been deleted, there have just been fraudulent copyright claims. We are working with YouTube to restore everything now. Thank you for your patience.
# about a minute ago · Like ·
# K lo nữa nhé các bạn ^^!
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.006449988, 'technology': 0.00014748289, 'music': 0.00018351706, 'lifestyle': 0.0100568365, 'travel': 0.98316216}
# Lớp học nhỏ nơi chúng mình chăm chỉ mỗi ngày <3
#
# ----------------
# F.A.C.E Fashion Workshop
# TP.HCM: 213A, Nam Kì Khởi Nghĩa, Q.3
# Hà Nội: Nhà 28, ngõ 221, Kim Mã, Q. Ba Đình
# www.facefashionworkshop.com
# Hotline:
# Hà Nội: 0915 160 668 - Ms Lan Phương
# Saigon: 0965147117 - Mr Hữu Hôn
# Hiểu thêm về F.A.C.E tại:
# www.goo.gl/LxoX5I
# www.goo.gl/Rg6z2H
# www.goo.gl/NT3Gq4
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.10056196, 'technology': 0.4839022, 'music': 0.00017542705, 'lifestyle': 0.41484013, 'travel': 0.0005201719}
# Hôm nay Na Quay chương trình "Moms in Town -Những Bà Mẹ Thành Thị" với Gào và chị Đoan Trang. Chương trình nói về tất cả những vấn đề của phụ nữ như là xử lý người yêu cũ chồng như thế nào, cách giữ dáng sau khi sinh, các vấn đề với người giúp việc ...vv... có ai quan tâm đến những chủ đề này không? Chừng nào lên sóng Na sẽ thông báo nghen.
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Prob: {'fashion': 0.05223427, 'technology': 0.5923453, 'music': 0.12987879, 'lifestyle': 0.005175211, 'travel': 0.2203665}
# mọi người ơi vào trang theo link bên dưới để cùng nhìn ngắm những hình ảnh tuyêt đẹp của NEXT TOP MODEl ở các mùa của các nước khác nhau nhé
# https://www.facebook.com/permalink.php?story_fbid=1548609765350450&id=1548274378717322&ref=notif&notif_t=like
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.00023749023, 'technology': 0.0008107991, 'music': 0.0052647097, 'lifestyle': 0.22035672, 'travel': 0.77333033}
# Tình hình các bảng đấu World Cup hiện tại 😍😂
#
# Không biết Messi có giữ được màu hay biến thành trắng đen hay không, chứ đang khóc rồi này 😂
#
# Các cầu thủ trong hình minh hoạ này đáng yêu quá ❤️Đêm nay mọi người có xem lượt 3 vòng bảng không?
#
# #loficielvietnam
# #worldcup
# #lovely
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 1.0605944e-05, 'technology': 0.003977641, 'music': 0.0012944514, 'lifestyle': 0.0005065426, 'travel': 0.99421084}
# Hí lô mọi người,
# Đây là clip anh Hiếu quay bằng phone trong chuyến đi này của gd Na. Mọi người xem trước nha. Mấy hôm nữa Na sẽ post hình và review cả chuyến đi. Clip này quay ở Krabi, Phi Phi island, và Railay. Các nàng nhớ bật HD ở dưới góc phải để xem cho rõ nghen.
#
# Love,
# Hannah
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.00016184832, 'technology': 0.9954522, 'music': 8.540765e-05, 'lifestyle': 0.003931253, 'travel': 0.00036928098}
# "Anh phải yêu thì mới làm.
#
# Tôi nghĩ kỹ thuật không quá quan trọng. Quan trọng nhất là cách người chụp dùng mắt, để tâm và trí vào việc chụp ảnh. Nếu muốn đưa chuyện chụp ảnh lên một tầm cao hơn, anh phải biết cách kể chuyện. Phải cảm nhận được câu chuyện khi anh bấm máy. Nhiếp ảnh rất đáng trở thành thứ nhớ nhung và ám ảnh”
#
# (Fan Ho)
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.25402144, 'technology': 0.001028579, 'music': 0.00025142875, 'lifestyle': 0.06788163, 'travel': 0.6768169}
# Chủ đề : Thể thao cao cấp.
# Họ và tên : Nguyễn Hoài Phong.
# Sinh ngày 20/5/1999
# Địa chỉ : ấp An Bình , xã An Thạnh 3 , huyện Cù Lao Dung , tỉnh Sóc Trăng.
# Sđt : 0965376220
# Số cmnd : chưa có
# Lấy ý tưỡng từ những cô gái võ thời xưa tuy rất mạnh mẽ nhưng rất diệu dàng và nữ tính
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.0024040267, 'technology': 0.90112674, 'music': 0.00028070025, 'lifestyle': 0.0922405, 'travel': 0.003947982}
# "Thường thì người ta không tin mình có thể làm được cái gì đó lớn lớn, và họ tin tuyệt đối vào điều đó. Thế nhưng khi bắt họ làm những thứ nhỏ nhỏ, thì họ lại càu nhàu, bảo rằng tôi sinh ra để làm việc lớn hơn."
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Prob: {'fashion': 0.016792579, 'technology': 0.093053035, 'music': 0.28524834, 'lifestyle': 0.23370789, 'travel': 0.37119815}
# "Dù mai sau kia gập gềnh sóng gió
# Dù mai sau kia dòng đời có cuốn xoay
# Dù nhắm mắt anh vẫn nắm tay em như ngày ta bắt đầu.."
# ---------------------------------------
# Ảnh: Bạn Ánh Dương gửi tặng Nghe Gì Hôm Nay <3
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Prob: {'fashion': 3.981821e-05, 'technology': 0.33735657, 'music': 0.65858394, 'lifestyle': 0.00016407784, 'travel': 0.0038556585}
# Đã nhận được giấy mời chính thức từ Samsung
# Anh em đợi livestream handon và mấy trò vui vẻ của ad nhé.
# Sự kiện sẽ diễn ra vào ngày 29 này, ở New York.
# Nghĩ đến hơn 20 tiếng bay cũng đuối lắm, nhưng sẽ vui vì được cầm em nó sau đó.
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Prob: {'fashion': 0.0019264845, 'technology': 1.1124438e-05, 'music': 0.000117478725, 'lifestyle': 0.9435361, 'travel': 0.05440882}
# Các cô gái có biết độc thân chính là thời khắc đẹp nhất của con gái <3
# Độc thân đồng nghĩa với việc có nhiều thời gian dành cho bản thân, đi những nơi mình muốn, ăn những món mình thích, gặp những người cần gặp..
# Đừng phí hoài thanh xuân của mình các cô gái nhé <3
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.0032736678, 'technology': 0.00016733928, 'music': 1.5464337e-05, 'lifestyle': 0.9965222, 'travel': 2.1377755e-05}
# Nữ hoàng đầm cưới cao cấp bridal couture Nhật Bản Yumi Katsura. Bà là người đầu tiên của Nhật Bản viết cuốn sách về thời trang đồ cưới. Và bà cũng sáng tạo ra một trong những chiếc đầm cưới mắc nhất thế giới khi đính kết một trong 2 viên kim cương hiếm duy nhất trên thế giới.
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Prob: {'fashion': 0.004437724, 'technology': 0.33404604, 'music': 0.6573315, 'lifestyle': 0.00012578137, 'travel': 0.004058962}
# chào nhóm tinh tế mình đã theo dõi rất nhiều video nhóm bên mình và thấy rất hay hôm nay mình mạn phép muốn nhờ bên mình xíu đc ko à. Số là mình muốn tìm video mà bên nhóm mình từng đăng nhưng h ko xem đc về cuộc chinh phục vịnh mariana của đạo diễn james cameron đc ko à tks you
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Prob: {'fashion': 0.270692, 'technology': 0.046387732, 'music': 0.5496136, 'lifestyle': 0.008183835, 'travel': 0.12512282}
# It's time to be the next Winner (y)
#
# Các bạn đã đăng kí để trở thành ứng viên của Vietnam's Next Top Model mùa này chưa ?
#
# Hãy nhanh tay đăng kí theo đường link bên dưới để biến ước mơ của mình thành sự thật nhé <3 :
#
# http://admin.vietnamnexttopmodel.com/index.php?option=com_contestants&view=register&Itemid=88&layout=register
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.0021003266, 'technology': 0.45392808, 'music': 0.0012601455, 'lifestyle': 0.35721764, 'travel': 0.18549384}
# Nói chung là review có tâm, làm một cái video review mặt nạ thôi mà đắp cả 800 loại lên mặt chể chọn loại tốt nhất cho các nàng nè. Yêu chưa???
#
# P.S. Tối nay sẽ post video giới thiệu một loại mặt nạ rất lạ mà Na thích, mọi người xem nghen!
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Prob: {'fashion': 0.01704924, 'technology': 0.26913872, 'music': 0.00019899136, 'lifestyle': 0.7118843, 'travel': 0.0017286238}
# Hãy tưởng tượng lúc bạn đang ở giây phút cuối của cuộc đời, bạn có ra đi thanh thản được không khi biết rằng mình có khả năng cứu sống mạng người, nhưng lại không làm vậy vì việc đó không đem lại tiền bạc gì cả?
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.09529348, 'technology': 1.7280672e-05, 'music': 2.3019084e-06, 'lifestyle': 0.1400477, 'travel': 0.76463926}
# Ngày mai bạn đã có kế hoạch đi đâu chưa? Cùng đến làm đẹp tại Women's Health Beauty Day nhé, rất nhiều dịch vụ làm đẹp hấp dẫn đang chờ bạn và đặc biệt hoàn toàn miễn phí bạn nhé.
# Hẹn gặp các bạn tại nhà văn hoá Thanh Niên, TP. HCM nhé!
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.04166525, 'technology': 0.001630616, 'music': 0.23911135, 'lifestyle': 0.7155254, 'travel': 0.0020673107}
# Trên Instagram, chuyên gia trang điểm gốc Việt Hung Vanngo vừa chia sẻ hình ảnh mới nhất của Selena Gomez khi cô ở hậu trường một buổi chụp ảnh.
# ------------------
# Phải nói càng ngày Sel càng xinh và quyến rũ :3
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Prob: {'fashion': 0.0014372837, 'technology': 0.053355526, 'music': 0.80639887, 'lifestyle': 0.09272167, 'travel': 0.046086624}
# Bữa giờ em này được mấy nàng thích mùi ngọt cưng quá nên mình không pr luôn 😘😍😍😍
# HUGO DEEP RED - ngọt như kẹo và siêu cưng nhé, ai muốn test mùi cứ qua Tr, test tẹt mùi luôn nhen 😘
# ❗Gọi Tr hoặc add zalo nhé: 0122 734 6060
# ❗ Tr cung cấp số lượng nhiều, giá cực kỳ tốt so với hàng nhập US nhé.
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Prob: {'fashion': 0.0014372837, 'technology': 0.053355526, 'music': 0.80639887, 'lifestyle': 0.09272167, 'travel': 0.046086624}
# Bữa giờ em này được mấy nàng thích mùi ngọt cưng quá nên mình không pr luôn 😘😍😍😍
# HUGO DEEP RED - ngọt như kẹo và siêu cưng nhé, ai muốn test mùi cứ qua Tr, test tẹt mùi luôn nhen 😘
# ❗Gọi Tr hoặc add zalo nhé: 0122 734 6060
# ❗ Tr cung cấp số lượng nhiều, giá cực kỳ tốt so với hàng nhập US nhé.
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Prob: {'fashion': 0.00033851032, 'technology': 0.99190605, 'music': 0.0021823316, 'lifestyle': 0.0009383948, 'travel': 0.0046346956}
# Đôi khi anh chỉ muốn bốc đầu vòng quanh thế giới :v
# Trong ảnh là Mamotoraman, một anh chàng người Nhật với chục ngàn lượt theo dõi trên Instagram nhờ ý tưởng độc đáo của mình.
#
# Tiện thể khảo sát 500 anh em: Nếu được chu du khắp năm châu, anh em sẽ chọn chụp ảnh theo công-xép gì? 😀
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.016627198, 'technology': 1.2575642e-06, 'music': 3.0683685e-05, 'lifestyle': 0.98333514, 'travel': 5.592696e-06}
# Tip: Áo khoác bomber hoạ tiết thêu đính là item rất được các bạn nữ ưa chuộng cho streetstyle thu đông năm nay. Bạn có thể phối item này với nhiều phong cách khác nhau  từ thướt tha nữ tính đến bụi phủi rock chic.
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.1899835, 'technology': 2.906442e-07, 'music': 1.9101875e-05, 'lifestyle': 0.80999655, 'travel': 4.3973563e-07}
# GRAMMYs 2017 năm nay lại tràn ngập những bộ cánh trong các BST mới nhất của Dior Valentino TOM FORD Roberto Cavalli Armani... Các tín đồ thời trang có đoán được các ngôi sao Hollywood đang mặc trang phục của nhãn hiệu nào không 😙
#
# #Grammys #2017 #bestdress #celebrities #redcarpet
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 2.9256733e-05, 'technology': 0.94155204, 'music': 0.0577114, 'lifestyle': 0.00013341781, 'travel': 0.0005738576}
# Hiện nay trên các MXH đang truyền tay nhau tin đồn thành viên của Momoland Jane từng là master-nim fansite của Infinite L và Sunggyu
#
# Fansite tên : Baby's Breath
# Mở 160808 và đóng 180221
#
# Hình fansite chụp : https://pbs.twimg.com/media/DWfA2fLVoAAnyiq.jpg
# https://pbs.twimg.com/media/DWfA3rVVMAIL-U7.jpg
# https://pbs.twimg.com/media/DWfA4sGVMAA4gB_.jpg
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.00038513882, 'technology': 0.9638707, 'music': 0.015985569, 'lifestyle': 0.010476894, 'travel': 0.009281696}
# Tình hình là hôm qua mấy cái đồng hồ hot bị sold out trong một nốt nhạc. Các mẹ kêu gào dzữ quá làm tui cũng bấn loạn phải gọi năn nỉ chêm hàng thêm. Tin buồn là hàng đã hết thì không còn nữa, nhưng họ có chêm thêm nhiều hàng mới cũng đẹp lắm nè. Mẹ nào hôm qua mua hụt thì vào đây xem nha: http://leflair.co/Hannah
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.36737064, 'technology': 3.259399e-07, 'music': 0.0004666163, 'lifestyle': 0.6309154, 'travel': 0.0012470211}
# Quán quân Vietnam's Next Top Model 2017 Kim Dung gây ấn tượng với vẻ đẹp ma mị trong bộ hình trên tạp chí L'Officiel Vietnam số tháng 9/2017 ✨
# Art Director: Alex Fox
# Photographer: Tam Mure (ThongHoang)
# Make up and Hair: Tùng Châu (Dash Ound) - Bummie (Kim Dung, Quang Thạch)
# Model : Dash Ound - Kim Dung - Quang Thạch
# Stylist: Mai Nguyễn
# Concept assistant: Khoa Lê
# #Gucci Shooting
#
# #teamKimDung #KimDee #Lofficiel
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.085223556, 'technology': 9.260781e-05, 'music': 0.4233323, 'lifestyle': 0.4367443, 'travel': 0.05460724}
# Dù nắng dù mưa, dù xa dù gần, ở nơi đó....vẫn có người luôn mong chờ ta trở về. Chỉ cần, con tim ta vẫn cứ luôn nồng nàn như thế 😊❤
# Hãy cùng ngủ say trong giai điệu trầm lặng với sáng tác mới của Phùng Khánh Linh nào cả nhà nhé 💓
# --------------------------------------------------------------------------------
# True: travel
# Pred: fashion
# Prob: {'fashion': 0.61492527, 'technology': 0.23177756, 'music': 0.12892805, 'lifestyle': 0.0030985058, 'travel': 0.021270612}
# [Thông báo CHÍNH THỨC về Gala mừng công ĐT U23 Việt Nam tại TP Hồ Chí Minh
#
# ° 17h00 ngày 4/2/2018
# ° SVĐ Thống Nhất
# ° Live: HTV TT
# ° Free vé
# Buổi Gala (dự kiến) có sự góp mặt của ca sỹ Đàm Vĩnh Hưng, Sơn Tùng M-TP...
#
# Nguồn tin: Vietnam Football
# Ảnh: Vntrip.vn
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 4.977898e-06, 'technology': 0.5129073, 'music': 0.109797806, 'lifestyle': 0.07547461, 'travel': 0.30181527}
# Đã có bản cover Vietsub của "Pen Pineapple apple pen" rồi =)))) Thánh nào lầy dễ sợ luôn :))
# Nên xem khi stress, buồn bực, cáu... vì tính giải trí cực kỳ cao <(")
# "Tao có 1 cây ziết
# Tao có 1 trái bơm
# ơ
# Bơm cây ziết
#
# Tao có 1 cây ziết
# Tao có 1 trái Thơm
# ơ
# Trái thơm cây ziết
#
# Cây ziết trái thơm
# Trái bơm cây ziết
# ơ
# Cây ziết bơm trái thơm cây ziết"
#
# ©: Eny Kuku
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 6.4525507e-06, 'technology': 0.94574994, 'music': 1.1466109e-06, 'lifestyle': 0.05422368, 'travel': 1.8796547e-05}
# Trong bài viết này chúng tôi sẽ SO SÁNH các dòng SẢN PHẨM BÌNH DÂN và CAO CẤP để giúp bạn tìm ra câu trả lời đâu mới là sự lựa chọn tốt nhất bạn nên đầu tư ngân sách của mình.
#
# Liệu bạn nên chi mạnh cho hàng hiệu để đổi lấy chất lượng hay giá rẻ để hợp túi tiền?
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Prob: {'fashion': 2.4460738e-07, 'technology': 0.99995565, 'music': 8.052699e-08, 'lifestyle': 5.360023e-07, 'travel': 4.3508786e-05}
# Mori Building DIGITAL ART MUSEUM
# ____
# Bảo tàng kỹ thuật số áp dụng công nghệ tiên tiến cùng màn hình LSD. Du khách vào đây như đang lạc vào xứ sở thần tiên với không gian 3 chiều có diện tích 10.000 m2, sử dụng 520 máy tính và 470 máy chiếu. Vào đây tha hồ sống ảo nhen 🎊
#
# Địa chỉ : Odaiba Palette Town, 1-3-8 Aomi, Koto-ku, Tokyo.
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Prob: {'fashion': 0.00032081595, 'technology': 0.014444048, 'music': 0.0056490805, 'lifestyle': 0.36353981, 'travel': 0.61604625}
# - Ê thằng đần, mày có ghệ chưa?
# - Đương nhiên là rồi, đồ ngu.
# - Ô ngon, ghệ mày người đâu đấy?
# - Nó người nước ngoài mày ạ.
# - Wtf thật à? Nước nào đấy?
# - Nước tưởng tượng :v
# ---------------------------
# Nguồn: 9gag
# Cơ mà ai hiểu nguôn gốc thì hay hơn nhiều :3
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 1.5734263e-06, 'technology': 0.0058737206, 'music': 3.8930326e-09, 'lifestyle': 1.7870679e-09, 'travel': 0.9941247}
# Chụp bộ ảnh thôi mà phải bay qua Paris rồi đi xe về Đà Lạt thiệt tốn kém quá chời hà :3
#
# #samsung #galaxyj7+ #galaxyj7plus #j7+ #xoaphong #livefocus #laynetdong #dualcamera #camerakep #jadebrun #thythy #shynathan47 #techrum #mobiography
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.0047987145, 'technology': 0.063761346, 'music': 0.16154326, 'lifestyle': 0.43237993, 'travel': 0.3375167}
# Chuyên sỉ/lẻ tinh dầu
# 😍 Nhập khẩu us, KHÔNG bán hàng Kim Biên, hàng fake
# 😍 Lưu hương trên 10h trên da, 2-3 ngày trên áo
# 😍 Chuẩn mùi (Chanel, Gucci, CK, Armani, Lacoste, Hugo,...)
# 😍 Ship toàn quốc
# 😍 Nước hoa tinh dầu cô đặc US
# 😍 Hơn 40 mùi của các nhãnhàng
# 😍 Chai đầu lăn siêu tiết kiệm (xài hơn 2 tháng)
#  Sỉ/lẻ : 0122 734 6060 (zalo/viber)
# https://www.facebook.com/tinhdaunuochoa1303
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.0005908579, 'technology': 0.00021931909, 'music': 5.6443507e-05, 'lifestyle': 0.0025425754, 'travel': 0.99659085}
# Tình hình là buổi chiều em đi làm mặt phê quá, nằm ngủ mất nửa tiếng. Đến lúc dậy thì bạn nv cũng massage xong. Em dậy quờ quạng thay quần áo rồi qua Takashimaya đi chơi và ăn tối với chồng con luôn. Đi khắp 4, 5 tầng trung tâm thương mại rồi đi ăn thì về mới phát hiện là mặc áo ngược. Em quê hương quá phải làm shao bây giờ 😳😳😳
#
# P.s. Xin hỏi hôm nay có ai lỡ gặp em không ạ??
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Prob: {'fashion': 0.6761814, 'technology': 4.607412e-08, 'music': 4.7543635e-05, 'lifestyle': 0.3236626, 'travel': 0.0001084472}
# ... Như một buổi hòa nhạc trong đám cưới Hoàng Gia...
#
# Xem buổi trình diễn BST Xuân Hè 2018 Atelier Zuhra Couture,  mà có cảm giác như đang ở buổi hòa nhạc trong đám cưới hoàng gia. Những chiếc đầm thanh lịch, tỏa sáng...
#
# - Fashion Forward Dubai -
#
# #AtelierZuhra #Couture #Wedding #Fashion
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.0153215565, 'technology': 0.050031528, 'music': 0.002170856, 'lifestyle': 0.2382617, 'travel': 0.69421434}
# Chương trình Làm Đẹp & Tập Luyện MIỄN PHÍ
#
# Lần đầu tiên tại Việt Nam, tạp chí Women’s Health kết hợp với trung tâm California Fitness & Yoga Centers (CFYC) tổ chức buổi thực hành Làm Đẹp & Tập Luyện MIỄN PHÍ hàng tháng cho các bạn nữ.
#
# Hãy đăng kí tham gia và nhận ngay quà từ The Body Shop tại đây nhé: http://bit.ly/16glk9q
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.23664646, 'technology': 0.00038152494, 'music': 0.009551007, 'lifestyle': 0.010997326, 'travel': 0.74242365}
# có khoảng hơn 40 tuần lễ thời trang của các thành phố khác nhau trên thế giới mỗi năm nhưng The Big Four (4 tuần lễ lớn nhất) danh giá là New York, London, Milan và Paris
#
# những tuần lễ nhỏ hơn được tổ chức ở những quốc gia xa thật xa như Croatia, Pakistan và thậm chí cả Iran
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Prob: {'fashion': 0.0014440167, 'technology': 0.042822566, 'music': 0.06250927, 'lifestyle': 0.00021146005, 'travel': 0.89301276}
# It's no secret that Michael Jackson was an inspiration to many. From his wardrobe and his music to his crotch-grabbing and moonwalking, a number of pop stars have taken cues from the late King of Pop, who died suddenly four years ago. Check out nine artists who are keeping M.J.'s memory alive onstage and beyond...
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.008913952, 'technology': 1.0702527e-06, 'music': 0.00013757529, 'lifestyle': 0.9908922, 'travel': 5.5213444e-05}
# Hương Ly - Ngọc Châu hội ngộ cùng dàn mẫu Vietnam's Next Top Model trong đêm ra mắt dòng sản phẩm mới nhất Classic Pettite đến từ Daniel Wellington
# Dress: Elpis Clothing
# Photo: beU - Tùng Chuôn
# #DanielWellington #Elpis #ELgirls
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Prob: {'fashion': 0.98987937, 'technology': 3.2525493e-06, 'music': 1.2413707e-05, 'lifestyle': 0.008411787, 'travel': 0.0016931092}
# Giữa bạt ngàn gió, nắng và khoảng xanh điệp trùng, con người nhỏ bé chỉ muốn tĩnh lại, tan ra để hòa làm một với nguồn sống thiên nhiên và giấc mơ thời trang kỳ diệu...
#
# Hình ảnh: Tuấn FR
# Stylist: Phương Anh
# Người mẫu: Hằng Nguyễn
# Trang điểm và làm tóc: Từ Minh Quân
# Dựng cảnh: Lý Binh Sơn
# Trợ lý: Hữu Duy, Tang Thanh Bình
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.00017442844, 'technology': 0.99425393, 'music': 0.0027674625, 'lifestyle': 0.001008252, 'travel': 0.0017958751}
# mình có cv kiếm tiền online nghiêm túc, không bán hàng, không lo chạy doanh số, k hô hào đa cấp, chỉ cần 15 - 30 phút online mỗi ngày đăng bài và xem quảng cáo của cty, tiền về theo ngày k phải chờ cuối tháng nhé. Ai quan tâm ib mình nhé
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.0001803552, 'technology': 0.038407832, 'music': 0.06457882, 'lifestyle': 0.0026550207, 'travel': 0.894178}
# MÙ ĐƯỜNG KHỔ LẮM CÁC MÀY ƠIII
# Đi đến đâu cũng chỉ thấy mình ở dưới... bầu trời 😂😂
# Các "thánh" mù đường đâu, hãy tag ngay đứa bạn thân vào đây để nhắc nhở chúng nó không bao giờ được bỏ rơi bạn
# 😂😂🤣
# Nguồn: Weibo
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.0065819877, 'technology': 0.0138238575, 'music': 0.012197005, 'lifestyle': 0.96424353, 'travel': 0.0031536464}
# [TRƯA NAY NGHE GÌ]
# Người ta thường nói phải hiểu nhau thì mối quan hệ mới bền chặt. Nhưng đôi lúc, hiểu nhau quá lại khiến con người ta dần chán nản rồi quay lưng đi. Đời sao trớ trêu quá nhỉ 😊
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 8.936046e-09, 'technology': 0.9997482, 'music': 0.00024095202, 'lifestyle': 1.0727475e-05, 'travel': 6.661996e-08}
# ...
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 0.0012140048, 'technology': 0.0952783, 'music': 0.13217072, 'lifestyle': 0.00087329984, 'travel': 0.77046365}
# https://www.facebook.com/wearethedwarves
#
# Our game tells the story of Dwarven Starship headed towards The Deep Stone Space in search of new energy sources. Due to the accident the Expedition fails. After the ship wreck only three Dwarven Astronauts survive, finding themselves in far outskirts of the Universe.
#
# http://steamcommunity.com/sharedfiles/filedetails/?id=279855788
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Prob: {'fashion': 0.004330568, 'technology': 0.0033373318, 'music': 2.037811e-06, 'lifestyle': 0.61852616, 'travel': 0.37380388}
# Bên cạnh việc phục vụ đồ ăn thức uống, các nhà hàng còn tạo nên sự khác biệt khi cung cấp các trải nghiệm tuyệt vời dành cho khách hàng của mình. Chính sự độc đáo trong cách phục vụ đã giúp các nhà hàng này trở nên nổi tiếng. Dưới đây chính là danh sách 17 nhà hàng mà bạn nên đến trải nghiệm một lần trong đời.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Prob: {'fashion': 0.84288603, 'technology': 4.8124615e-11, 'music': 2.4102158e-08, 'lifestyle': 0.15711398, 'travel': 1.5272212e-08}
# Trái ngược hẳn với hình ảnh hào nhoáng trên sàn catwalk, hậu trường của buổi biểu diễn bao giờ cũng thật náo nhiệt, tất bật. Hãy cùng L'Officiel Vietnam ghé mắt qua hậu trường của show diễn thời trang lớn nhất làng mốt Việt vừa diễn ra vào đêm qua - Vietnam International Fashion Week.
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 3.4552162e-08, 'technology': 0.15446395, 'music': 1.3860637e-05, 'lifestyle': 3.329447e-08, 'travel': 0.84552217}
# Ra đi chiếc ex 62zz
# Bình nắp chao
# Pô air Ycs
# Lòng trái Ycs
# Ic redleo 8 nấc
# ...vv...vv có j inbox
# Giá Ra đi : 35xxxxx ( còn fix nha )
# Đang chạy gắp NSR ....
# Xe ko có 1 tiếng động lạ nhé !! Bao êm !!
# Hotline : 0902983056
# Mua xe $ triệu đừng tiếc 1 cuộc gọi
# Xem xe tại Quy Nhơn !! Ahbp Tha e ! Miễn típ cò lái !!
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 0.00026474937, 'technology': 0.92365867, 'music': 0.05076407, 'lifestyle': 0.025184324, 'travel': 0.00012828805}
# Tưởng chừng như đó chỉ là một cái tên vui do các fan chế ra, nhưng sự thật là hồi còn học cấp 3 Carrie Underwood từng bị gọi là... Scary Underwear! Quả là một sự trùng hợp ngẫu nhiên lý thú.
#
# http://www.youtube.com/watch?v=eF9Qdz-S5Q0
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 1.6536487e-07, 'technology': 0.9894605, 'music': 0.010529854, 'lifestyle': 5.4338075e-06, 'travel': 4.0378814e-06}
# 6 BXH lớn tại Hàn Quốc bao gồm Melon, Genie, Naver, Bugs, Mnet và Soribada sẽ đóng băng Bxh realtime từ 1h - 7h sáng. BXH sẽ không được hiển thị vào các khung giờ này, tuy nhiên dữ liệu vẫn được ghi nhận.
#
# Động thái này nhằm ngăn chặn các fandom thực hiện hiệu ứng Zombie Streamer, thời gian mà các bài hát của idol họ leo thang trên các BXH realtime.
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.0009761645, 'technology': 0.0068769776, 'music': 0.021497857, 'lifestyle': 0.8823568, 'travel': 0.08829221}
# Chuyên sỉ/lẻ tinh dầu
# 😍 Nhập khẩu us, KHÔNG bán hàng Kim Biên, hàng fake
# 😍 Lưu hương trên 10h trên da, 2-3 ngày trên áo
# 😍 Chuẩn mùi (Chanel, Gucci, CK, Armani, Lacoste, Hugo,...)
# 😍 Ship toàn quốc
# 😍 Nước hoa tinh dầu cô đặc US
# 😍 Hơn 40 mùi của các nhãnhàng
# 😍 Chai đầu lăn siêu tiết kiệm (xài hơn 2 tháng)
#  Sỉ/lẻ : 0122 734 6060 (zalo/viber)
# https://www.facebook.com/tinhdaunuochoa1303
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Prob: {'fashion': 0.0027507506, 'technology': 3.1162508e-05, 'music': 0.44133264, 'lifestyle': 0.52610046, 'travel': 0.029784966}
# #HappyDASOMday 06/05/1993 - 06/05/2018
#
# Mọi thứ xung quang đều lu mờ chỉ có nhan sắc của Somie là tỏa sáng.
# Chúc Somie sinh nhật vui vẻ, tuổi mới nhiều thành công mới sẽ đến với gái nhé. Mãi yêu <3
# .
# .
# .
# Quan trọng là sớm có bồ đi má ơi :)))))))))
#
# cre: @abybomhana
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.0004133991, 'technology': 0.9593653, 'music': 0.0015869114, 'lifestyle': 0.01869185, 'travel': 0.019942448}
# Internet được thiết kế để lưu trữ gần như vĩnh cửu mọi thứ được đưa lên nó. Vì thế hãy suy nghĩ kỹ lưỡng những gì bạn đưa lên Internet, một ngày nào đó bạn sẽ bị quá khứ số của chính mình ám ảm ảnh.
#
# (FB Hong Phuc Nguyen)
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.00054051826, 'technology': 0.8582669, 'music': 0.000118022275, 'lifestyle': 0.14093372, 'travel': 0.00014078601}
# Còn mấy bữa nữa là sinh nhật bà Na.  Chỉ muốn cảm ơn các loại kem dưỡng, kem chống nắng, botox, máy dưỡng mặt, các thể loại makeup và kem che khuyết điểm đã giúp cho Na 34 tuổi mà nhìn như 33. kkkk
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.00010237838, 'technology': 0.7616726, 'music': 0.00023878647, 'lifestyle': 0.108489096, 'travel': 0.12949708}
# BẠN ĐANG ĐAU ĐẦU VÌ HÓA ĐƠN TIỀN ĐIỆN QUÁ NHIỀU SỐ?
# Công tơ điện nhà bạn quay với "tốc độ bàn thờ"?
# Hãy làm theo những mẹo sau đây, đảm bảo các bạn sẽ tiết kiệm được một khoản chi phí kha khá đấy ;)
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Prob: {'fashion': 0.0010610684, 'technology': 0.9972627, 'music': 6.694136e-05, 'lifestyle': 0.0014791093, 'travel': 0.00013012924}
# Tiến Mạnh bật khóc sau cuộc gọi điện về gia đình.
#
# Nếu mem từng phải ở trong nhà chung, không có bất cứ một phương tiện nào để liên lạc với "thế giới bên ngoài" thì mem sẽ hiểu được cảm giác của Tiến Mạnh lúc này...
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.20807259, 'technology': 0.00084754004, 'music': 0.00040691157, 'lifestyle': 0.7761931, 'travel': 0.014479857}
# Chuyên viên trang điểm Trương Khanh 0988 805 922
# Trang điểm, làm tóc cho: cô dâu.
# Trang điểm, làm tóc phục vụ chụp hình, quảng cáo, quay phim.
# Trang điểm, làm tóc đi tiệc, dạ hội.
# Dạy make up cá nhân tại nhà của khách hàng.
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 0.0003437488, 'technology': 0.9977062, 'music': 0.0017262694, 'lifestyle': 4.8532533e-05, 'travel': 0.00017537076}
# Tiếp tục tham gia Minigame Sao88 của Yeah1 để nhận album nóng bỏng tay của idol mình yêu thích nhất nhé
# Mọi chi tiết cuộc thi xem tại link:
# https://www.facebook.com/bangxephangamnhackpop.vn/photos/a.1770425269888331.1073741833.1706544702943055/2012612029002986/?type=3&theater
#
# http://yeah1.com/sao88/thanh-xuan-cua-em-mang-ten-super-junior-1.html
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.31070295, 'technology': 0.08575789, 'music': 0.14424984, 'lifestyle': 0.0031686057, 'travel': 0.45612064}
# MODEL CASTING CALL
# ( Female Model Shoooting)
#
# Hello Model! Now we are looking for some foreign models for bikini photoshoot - Concept Party- on Nov 20 - 22th.
#
# Anyone who is interested  in this job please send us your compcard for casting first.
#
# Thank you and have a nice weekend!
#
#
# For more information:
# E-mail: contact@beumodels.com
# Tel: 0902 296 298
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 1.690674e-06, 'technology': 3.028316e-07, 'music': 1.2025035e-07, 'lifestyle': 0.0002485801, 'travel': 0.99974924}
# Du lịch với bạn, với người yêu, với gia đình thì tất nhiên sẽ vui. Nhưng đi du lịch một mình cũng là trải nghiệm mà bạn nên thử. Tuy nhiên, mình vote đi một mình ở nước ngoài hơn, nếu bạn không ngại rào cản ngôn ngữ. Bởi có nhiều quốc gia khác có độ an toàn cao nếu bạn sợ đi một mình.
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Prob: {'fashion': 4.5718022e-07, 'technology': 0.8646773, 'music': 3.830585e-08, 'lifestyle': 1.3309517e-08, 'travel': 0.13532214}
# ⚠ LÀM SAO ĐỂ TRÁNH 【MẤT CẮP】KHI ĐẶT PHÒNG ONLINE
# ---
# Gần đây nhiều bạn inbox hỏi page về vấn đề Agoda, Booking .com... một số web đặt phòng của nước ngoài thừa nhận để lộ thông tin thẻ tín dụng của khách hàng 😣.
#
# Vietnam Travel lưu ý các bạn 1 vài điều để thanh toán an toàn trên các hệ thống đặt khách sạn trực tuyến nhé! (chi tiết trong từng ảnh)
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.014641056, 'technology': 1.9090008e-07, 'music': 1.4461458e-08, 'lifestyle': 0.9853587, 'travel': 1.1190663e-09}
# "Người đẹp vì lụa" hay "Lụa đẹp vì người"?
# Thời trang không chỉ đơn thuần là khoác lên người vài lớp vải được may vá, mà đằng sau đó còn là cả câu chuyện.
# Một bài viết cực kỳ thú vị cho những ai quan tâm thời trang đến từ ELLE: https://www.lofficiel.vn/emagazines/thoi-trang-va-co-the-ai-giai-phong-ai/index.html
# #beUmodels #beUmgmt #fashion #story #model
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.010615797, 'technology': 0.04648274, 'music': 0.27738816, 'lifestyle': 0.06837619, 'travel': 0.59713715}
# Ôi Na hư đốn quá mọi người ơi, workshop cả hai tuần trước mà hôm nay mới có hình để post. Do trục trặc kỹ thuật tí, mọi người thông cảm nghen. (thảo mai tí vậy thôi chứ biết là thông cảm mà, hihiihi)
#
# Một lần nữa chân thành cảm ơn mọi người đã ủng hộ Na nghen!!!
#
# À, mọi người tự do tag hình, copy hình mình về thoải mái nghen.
#
# Love,
# Hannah
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Prob: {'fashion': 0.005421332, 'technology': 0.32973737, 'music': 0.0044444343, 'lifestyle': 0.27012438, 'travel': 0.39027247}
# Đây chính là phong cách của GK Tùng Leo sao ???? V cho hỏi a có học đại học ko??? Hay như thế nào. Vội vàng gì đánh giá nv chứ nếu k có đam mê đi thi làm gì ????? Cuộc thi này đề ra để thi tay nghề và cái đức. Chứ k phãi đi thách thức tinh thần.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# Prob: {'fashion': 0.031587806, 'technology': 0.06528616, 'music': 0.8525315, 'lifestyle': 0.05028419, 'travel': 0.0003103332}
# Xưa nay chưa từng mời ai làm gương mặt đại diện, nhưng mới đây hãng Sulwhasoo đã mời nữ diễn viên Song Hye Kyo làm đại sứ thương hiệu cho mình. Cùng ngắm nàng "Hậu duệ mặt trời" trong video mới nhất <3
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Prob: {'fashion': 0.39204976, 'technology': 0.0028548825, 'music': 0.0167163, 'lifestyle': 0.58151305, 'travel': 0.0068659745}
# Hà Nội !
# Mình cần gấp 1 bạn làm mẫu tóc nữa cho chương trình Việt Nam Nexttop Hair ngày 30-5
# Yêu cầu MÁI DÀI ĐẾN CẰM, TÓC DÀI CHẤM VAI là ok, TÓC CHƯA NHUỘM ĐEN, ĐỎ. cao 1m65 trở lên, gương mặt thon, mũi cao
# CASTXE CAO
# Ai làm đc ib mình ảnh + sđt nhé
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# Prob: {'fashion': 0.2686714, 'technology': 0.20976715, 'music': 0.34777746, 'lifestyle': 0.15164936, 'travel': 0.022134654}
# Hôm qua chị có đăng ký lớp 16 phút yoga trên ghế mỗi ngày . Sau đó chị có hỏi lớp yoga cho vẻ đẹp và sức sống. Chị có báo là ko đặt lớp này nhưng sao vẫn giao chị chị vậy ad? Chị đã đăng ký 2 lớp rồi và giờ muốn trả lại lớp này thì như thế nào?
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Prob: {'fashion': 0.0010209717, 'technology': 0.85480756, 'music': 0.10176762, 'lifestyle': 0.0011746358, 'travel': 0.041229237}
# Ad cho mem PR tý nhar....các bạn có thể vui lòng trích chút thời gian quý báu của các bạn để ghé qua shop của mình để tham quan được không? À nếu bạn thích thì hãy like cho mình nhé! Gửi ngàn lời cảm ơn đến các bạn!
# Shop đang có game m.n tham gia để có cơ hội nhận quà nha ! :)
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 4.777653e-06, 'technology': 0.2427214, 'music': 6.367907e-09, 'lifestyle': 6.697566e-07, 'travel': 0.7572731}
# [TET18] Team Sài Gòn cũng cùng mối bận tâm khi Đà Lạt hay Vũng Tàu đông như kiến. Hãy tư vấn cho người anh em một địa điểm xịn đét đi chơi Tết nào!
#
# Anh em mê du lịch có vào: https://tinhte.vn/dulich/ để chia sẻ và hỗ trợ nhau nhé!
#
# #Tinhte #Tet18
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Prob: {'fashion': 0.95636386, 'technology': 0.00083527894, 'music': 0.004245515, 'lifestyle': 0.038083285, 'travel': 0.00047202533}
# Sự ngọt ngào của cặp soul-mate làng thời trang Việt Đoàn và Adrian Anh Tuấn, vốn không chỉ được đong đếm bởi những thành công chốn lụa là.
#
# Trên tất cả, Tuấn và Sơn khi nào cũng muốn cùng nhau trải nghiệm cuộc sống, đắm chìm trong những mật ngọt của tình yêu...
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Prob: {'fashion': 0.008963135, 'technology': 0.95342445, 'music': 6.834453e-05, 'lifestyle': 0.037423998, 'travel': 0.00011997769}
# Việc làm việc theo nhóm tưởng dễ nhưng hóa ra lại là một thử thách “đau đầu” bởi khả năng lãnh đạo của trưởng nhóm cùng kĩ năng hòa hợp cùng nhau sẽ là yếu tố được đặt lên trên cùng. Bởi việc kết hợp các cá tính để đi theo một định hướng thống nhất là một việc không hề dễ dàng, đặc biệt là khả năng lãnh đạo của trưởng nhóm.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Prob: {'fashion': 0.0048185773, 'technology': 0.7509634, 'music': 0.00071585394, 'lifestyle': 0.20248123, 'travel': 0.041020963}
# 10 ĐIỀU CON TRAI LUÔN NGHĨ TRONG ĐẦU NHƯNG KHÔNG DÁM NÓI RA 😂😂😂
# Những điều này quả thực rất khó nói đấy, các bạn gái tag con trai vào xem đúng bao nhiêu trên 10 nào! Mình thì thấy đúng 9/10 rồi 🤣
# nguồn: Zing.vn
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Prob: {'fashion': 0.0001381591, 'technology': 2.3300787e-05, 'music': 7.6318705e-05, 'lifestyle': 0.21475796, 'travel': 0.78500426}
# Có ai đang mệt mỏi vì Tết không? Na Tết năm nào cũng khoẻ re vì toàn đi du lịch thôi. Nhưng vì vậy mà đôi khi Na lại thấy buồn buồn vì cảm giác bị thiếu thiếu gì đó. Kiểu như bị mất gốc á.  Nên năm nay Na cũng muốn mình bận rộn hơn một tí để chuẩn bị đón tết cho có không khí.
#
# Mọi người xem tâm sự của Na, chị Đoan Trang, và Gào trong tập mới này về Tết nha.
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Prob: {'fashion': 0.0014234317, 'technology': 0.23373768, 'music': 2.7227827e-06, 'lifestyle': 0.0019228427, 'travel': 0.7629134}
# Từ 1-6/6 đang có một triễn lãm vào cửa tự do cho những ai yêu Chùa, yêu sự thanh bình, tĩnh lặng, yêu danh thắng và con người Việt Nam hay chỉ đơn giản là yêu niềm đam mê của một người Pháp được hun đúc trên chính mảnh đất hình chữ S này.
#
# https://tinhte.vn/threads/moi-xem-trien-lam-anh-vietnam-pagodas-nicolas-cornet-tu-01-6-10-6-tai-sai-gon.2800414/
#
# #Tinhte #NicolasCornet
# --------------------------------------------------------------------------------
# Total: 176

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression(verbose=1, solver='lbfgs', multi_class='auto', n_jobs=4)

# %%
train_data = np.stack([x[0] for x in X_train], axis=0)

# %%
classifier.fit(train_data, y_train)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:   11.6s finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='auto', n_jobs=4,
#           penalty='l2', random_state=None, solver='lbfgs', tol=0.0001,
#           verbose=1, warm_start=False)

# %%
test_data = np.stack([x[0] for x in X_test], axis=0)

# %%
test_pred = classifier.predict(test_data)

# %%
print(classification_report(y_true=y_test, y_pred=test_pred))
# Out:
#               precision    recall  f1-score   support
#
#      fashion       0.60      0.58      0.59       583
#    lifestyle       0.61      0.64      0.63       981
#        music       0.61      0.58      0.59       597
#   technology       0.66      0.68      0.67      1029
#       travel       0.69      0.67      0.68       722
#
#    micro avg       0.64      0.64      0.64      3912
#    macro avg       0.63      0.63      0.63      3912
# weighted avg       0.64      0.64      0.64      3912

# %%
count = 0
for yp, yt, (_, mess) in zip(test_pred, y_test, X_test):
    if yp != yt:
        count += 1
        print('True:', yt)
        print('Pred:', yp)
#         print('Prob:', {c: p for c, p in zip(class2idx.keys(), pr)})
        print(mess)
        print('-' * 80)
print('Total:', count)
# Out:
# True: technology
# Pred: music
# Trên tay Samsung Galaxy A8/A8+. Anh em nhớ bình luận để trúng Loa Bluetooth JBL GO và chân máy Mefoto Mini Selfie.
#
# 88 khách hàng đầu tiên đặt hàng trước A8, A8 Plus tại Tiki.vn sẽ được nhận thêm Adapter Sạc Không Dây Tronsmart 10W QC2.0 - WQ10 trị giá 600k. Link đặt hàng Tiki: http://bit.ly/SamsungA8_Tiki.
#
# Livestream sponsor by Tiki #Tinhte #SamsungA8
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Dù chưa thật sự hoàn hảo, nhưng đây chính là niềm hi vọng cho những bệnh nhân có khuôn mặt bị biến dạng nặng, do tại nạn hoặc bệnh tật mà không thể khôi phục bằng phẫu thuật thẩm mỹ.
#
# #GenK
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Nếu bạn thích chinh phục những cung đường mạo hiểm thì đây chính là gói bảo hiểm dành cho bạn. Bảo hiểm FWD đang tặng MIỄN PHÍ 100,000 gói bảo hiểm tai nạn cá nhân, bảo hiểm đến 300 TRIỆU ĐỒNG. Nhanh tay đăng ký và nhận ngay gói bảo hiểm chỉ trong vòng 3 phút tại: https://tiki.vn/top/fwd
# #FWDbảohiểm #Sốngđầytừhômnay
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# [Rocks] MV mới của Future và Nicki Minaj cũng mới ra đây. Cả MV chỉ có mỗi một kiểu là chị Nicki mặc-mà-gần-như-không-mặc khoe body khắp đây đó thu hút ánh nhìn. :)). Lyric cũng ko có gì đặc sắc khi rap ngày nay toàn butt với sex với hoes và hát đi hát lại 1 kiểu ... Nói chung là Ad thấy ko có gì đặc sắc lém. Được cái chị sexy thế thôi. *Chấm nước mắt*.
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# 16:15 sẽ Trên tay và tặng pin đi động Tronsmart Presto 12000mAh, QC3.0...
#
# Game kết thúc ngày mai. Nội quy ở dây http://tinyurl.com/h8y2l5t
#
# Link sản phẩm: http://tronsmart.com.vn/san-pham/pin-du-phong-tronsmart-presto-12000-mah-quick-charge-3-0/
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# Album được sưu tập từ FB bạn Huyền Phạm (https://www.facebook.com/HuyenCherry93) và FB Món Ngon Hà Nội (https://www.facebook.com/HNmonngon)
#
# ALBUM vẫn còn đang cập nhật tiếp. Ôi nhiều món quá update không xuể được ạ.
#
# #Nhim
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Homestay siêu lãng mạn này được anh chủ có tâm hồn nghệ sĩ tự tay thiết kế lên chỉ để ở - giao lưu và không dinh doanh. Ngôi nhà nằm giữa đồi xung quanh thiên nhiên cực kì đẹp luôn í.
# Rủ bạn bè tới khám phá liềnnn <3
#
# Nguồn Foody
#
# #checkinvietnam #na
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# ✨ Các nhóc tì lại giành được vé mời tham dự show #VIFW #FW2017 ✨
#
# Với những màn nhảy bốc lửa, tạo dáng siêu ngầu, không có lí do gì mà các fashionista nhí của chúng ta lại không nhận được vé đúng không ❤❤
#
# #VIFW2017
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# 5 trò cảm giác mạnh nhất định phải thử trong dịp Tết cùng hội bạn thân :3
# Tết tụi m đã có kế hoạch đi đâu chưa, ghé công viên chơi vài trò cảm giác mạnh cho năm mới phê pha nàooo
# #Tag đồng bọn vào ngayyyy
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Hãy thư giãn bằng những ca khúc nhạc Việt lời tiếng Anh để thoải mái hơn nha ^^
# Ưu đãi Tết 2018, giảm 50% học phí, học ngoại ngữ Online cho người bận rôn tại:
# -  Nền tảng tiếng Anh cho người mất gốc: https://goo.gl/LgsfqH
# -  Học tiếng Anh giao tiếp tại: https://goo.gl/KcAQ8Y
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Ngọt lịm tim mất thôi với giọng hát nhẹ tênh nhưng đầy cảm xúc của Uyên Pím trong ca khúc Nhẹ cực chill đây cả nhà ơi <3 Chưa kể đến bài hát này cực hợp với những cảnh quay trong suốt tại Nhật trong phim Nhắm Mắt Thấy Mặt Trời đấy <3
# Cùng thưởng thức nhé cả nhà! :3
#
# https://www.nhaccuatui.com/playlist/nhe-nham-mat-thay-mua-he-ost-single-uyen-pim.7Sb6DmtlCfdx.html
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Bất ngờ với hình ảnh lột xác với hình ảnh mới với dòng nhạc Bolero của nữ ca sĩ Thủy Tiên, ngọt hơn mía lùi luôn cả nhà ơi 😍😍
#
# http://www.nhaccuatui.com/playlist/doi-mat-nguoi-xua-thuy-tien.Z7n5xzTtbNku.html
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Full danh sách trao giải + biểu diễn tại Golden Disc Award ngày 1
#
# -Bonsang : Black Pink , Heize , Bolbbalgan4 , Akadong Musician , TWICE , WINNER , BIG BANG, Yoon Jong Shin,Red Velvet,IU,BTS
#
# -Best Rock Band : Hyukoh
#
# -New Artist of The Year : Wanna One
#
# -Best RB/Soul : Suran
#
# -Best Female/Male Group : GFRIEND , BTOB
#
# -Daesang : IU 'SONG OF THE YEAR'
#
# cre : oh_mes
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# Bạn đã đọc tạp chí ELLE Tháng 10 chưa? Ngôi sao trẻ tài năng nào đã để lại ấn tượng lớn nhất với bạn? Một Minh Hằng chín chắn hay Kimmese và Suboi trẻ trung?
#
# Và đừng quên chia sẻ cảm nghĩ của bạn về ELLE ở đây: http://bit.ly/PmNvcd để nhận được quà tặng rất đáng yêu nhé!
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Ddu-Du Ddu-Du của BLACKPINK đã đạt 1,015,669 lượt người nghe độc nhất trên Melon sau 24 giờ phát hành đầu tiên. BLACKPINK trở thành nhóm nhạc nữ có lượt người nghe độc nhất trong 24 giờ cao nhất.
#
# Via BLACKPINK_INTL
# Cre: YGLV
# #Yii
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# [Xin phép Ad cho PR 1 chút ạ :3] Trang chuyên dịch tin US - UK, Kbiz từ các trang chính thống^^ Ngoài ra còn có các clip về đồ ăn, phim ảnh, phương pháp học tiếng Anh, Hàn và nhiều thông tin khác ^3^ Mong mọi người ủng hộ page nha ❤ #Kpop #Kbiz #USUK
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Việt Nam lần đầu tiên có Tuần lễ thời trang quốc tế (Y) #VIFW FIDé Fashion Weeks
#
# http://news.zing.vn/Viet-Nam-lan-dau-tien-co-Tuan-le-thoi-trang-quoc-te-post433807.html
#
# Buổi họp báo chính thức diễn ra vào sáng 6/7 công bố về kế hoạch tổ chức một tuần lễ thời trang được dự báo là sôi động nhất từ trước đến nay...
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# ELLE chúc mừng 3 người đẹp đã có chia sẻ được nhiều người like nhất trong trò chơi "Son đỏ yêu thích nhất của bạn là gì?":
#
# 1. An Binh: 571 likes
# 2. Nguyen Thi PHuong Dung: 562 likes
# 3. Hai Chi: 462 likes
#
# ELLE sẽ liên hệ với các bạn để trao quà là một bộ son bóng Clinique và chì kẻ chân mày The Body shop.
#
# Chúc mừng 3 bạn!
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Các bạn ơi!! Mình đang tính đi Mũi Né cùng các bạn mình khoảng 10 ngày nữa. Nhưng mình không biết nhà nghỉ khách sạn nào ở gần trung tâm để thuận tiện đi lại. Mình đi 4 người, khoảng 3 ngày. Mong các bạn gợi ý cho mình giá bình dân 1 tí!
# Cảm ơn các bạn xem qua và cho ý kiến! :)
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# DU LỊCH ĐÀ NẴNG chỉ với 80K/ ngày
# Giường đơn trong phòng ngủ tập thể 6 giường đầy đủ nội thất, máy lạnh….dành riêng cho phượt thủ và các solo travelers
# Chi tiết tại:
# https://www.facebook.com/The-Buddy-Hostel-%C4%90%C3%A0-N%E1%BA%B5ng-1671355383140595/?ref=aymt_homepage_panel
# Gmail: thebuddyhostel@gmail.com
#
# Rất hân hạnh được đón tiếp quý khách!
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Chào các bạn, tôi đang tìm học sinh để dạy kèm tiếng anh với giá rẻ, với kinh nghiệm giảng dạy của tôi hứa sẽ sớm mang đến cho bạn kết quả tốt và nhanh nhất. xin vui lòng liên hệ với tôi qua số điện thoại : 0985446704 (Nash)
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# Lẽ giản đơn
#
# đã bao giờ em bóc lịch
# thấy qua vô nghĩa một ngày
# rồi em ghi vào nhật ký:
# …ngày mai như ngày hôm nay…
# đã bao giờ em hoảng hốt
# khi mình bất lực trước mình
# và em thấy trong đôi mắt
# có gì ứa ra
# vô hình
# nếu có xin em đừng sợ
# thật ra là rất bình thường
# tất cả chúng ta đều thế
# mỗi khi cần được yêu thương
#
# - Nguyễn Thế Hoàng Linh
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Hãy cùng xem lại những hình ảnh hậu trường và casting của nhà thiết kế Yumi Katsura được trình diễn tối qua. Phía sau một show diễn tuyệt vời là sự lao động hăng say của tất cả mọi người. Từ nhà thiết kế, người mẫu, biên tập viên và cả những con người tất bật trong hậu kì.
# #backstage #YumiKatsura #VietnamInternationalFashionWeek
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# The new collection from Ly Giam Tien <3.We will share more images soon !!!
#
# Bộ sưu tập của Lý Giám Tiền vừa ra mắt tại chung kết Vietnam's Next Top Model <3.Hãy cũng theo dõi VIFW để xem trọn bộ sưu tập này nhé !
#
# Project Runway Vietnam beU Model Management
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# CON ĐƯỜNG TỎA SÁNG CỦA ARIANA GRANDE
#
# Chỉ còn chưa đầy 2 tháng nữa, fan hâm mộ Ariana Grande sẽ chào đón thần tượng của mình đến Việt Nam. Còn bây giờ, nhân ngày sinh nhật của Ari, hãy cùng ELLE nhìn lại hành trình tỏa sáng của cô công chúa nhỏ ngày nào đến "dangerous woman" ngày hôm nay <3
#
# Chúc mừng sinh nhật Ari <3 <3 <3
#
# #ellevn #ellevietnam #ArianaGrande
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# AWAY WE GIVE 🎁
#
# Trưa mai #AwayWeWow sẽ bắt đầu có những sản phẩm rất dễ thương để tặng các bạn kéo dài suốt tháng 9 và 10 nhé, mọi người nhớ tham gia để nhận quà nha. Thông tin chi tiết sẽ được post tại đây vào trưa mai nha <3
#
# From tomorrow we will have lots of different gifts to give away all this and next month so check back to join us and take away your free gifts guys. More details coming tomorrow 🎁
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Mùa "xê dịch" đã chính thức gõ cửa, và câu hỏi làm sao để đẹp mọi lúc luôn khiến những cô nàng sành điệu băn khoăn. Để giải đáp câu hỏi này không ai có thể tốt hơn những ngôi sao quốc tế, luôn phải di chuyển liên tục và giữ hình ảnh của mình đẹp nhất.
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Hôm qua xem cái báo cáo tài chính, lượt view video Facebook tận 8 tỷ lượt mỗi ngày, cao gấp đôi YouTube hết hồn luôn ...
#
# http://genk.vn/internet/ly-do-facebook-co-toi-8-ty-luot-xem-video-moi-ngay-la-day-20151106121541755.chn
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Anh em downvote ở đâu cũng được, nhưng downvote ở Fanpage Tinhte thì anh em là người xấu đó 😒😒😒
#
# Lỡ có gì không hài lòng thì anh em nhớ bình luận dưới mỗi bài để mình sửa, chứ âm thầm downvote, bị đuổi việc thì các mod cạp đất mà ăn thôi 😭😭😭
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Ông Nguyễn Thanh Hưng, Chủ tịch Hiệp hội Thương mại điện tử Việt Nam cho biết, Hiệp hội đã có buổi làm việc với đại diện của tập đoàn Amazon vào tuần trước. Theo đó, Việt Nam đang là thị trường nhận được sự quan tâm của Amazon. Đại diện Amazon cũng chia sẻ 2 bước chiến lược khi hoạt động tại Việt Nam.
#
# #Genk
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Lời nói chỉ là sáo rỗng, cách làm và kết quả mới là điều quan trọng
# Giá trị đó có ai hiểu thấu .🐒!?
#
# https://www.facebook.com/groups/536260456747103/?multi_permalinks=537760159930466&notif_id=1515642911336722&notif_t=group_activity
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# GIỌNG HÁT CHÍNH CỦA LINKIN PARK- CHESTER, TỰ TỬ BẰNG CÁCH TREO CỔ HÔM QUA!
# Giọng ca chủ chốt của nhóm nhạc đình đám Linkinpark, đã qua đời do treo cổ tự vẫn tại nhà riêng ở  Palos Verdes Estates bang LA. Thi thể của anh được phát hiện vào thứ Năm trước 9 giờ sáng giờ địa phương.
# Linkin Park Chester Bennington ra đi khi anh 41 tuổi.
# ----------------------------
# Mong anh yên nghỉ :)
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# SELENA GOMEZ - HẠNH PHÚC MỈM CƯỜI SAU NHỮNG KHỔ ĐAU
#
# Xuất phát điểm là một công chúa Disney cùng với Miley Cyrus và Demi Lovato, dù chặng đường phát triển khác nhau và trải qua nhiều thăng trầm trong cuộc sống, Selena Gomez giờ đây đang rất hạnh phúc với sự lựa chọn của bản thân mình.
#
# Chúc mừng sinh nhật Selena <3
#
# #ellevn #ellevietnam #SelenaGomez
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Like giùm nhỏ bạn................. Chỉ 1' thôi ! Đăng ký tại http://www.daisuthethaohocduong.com.vn/dang-ky.aspx
# Bình chọn tại:
# http://www.daisuthethaohocduong.com.vn/thi-sinh/257/nguyen-thi-kim-ngan.aspx
# ~~! Làm giùm nhỏ bạn ! Giúp nhá Thấy giề mừ tội qué ................ >"< ! Thanks
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Đánh tan nóng hè với các MÓN CHÈ nào các chị em 😍
# Vừa ngon mát, vừa an toàn, lại có dịp khoe tài lẻ nữa chứ hihi. Nhiều lợi ích quá trời luôn 😘
# Nhìn thế thôi chứ làm dễ lắm ạ, mời chị em vô đây học bí quyết nè: https://goo.gl/JtNBde
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Cùng diện bộ trang phục nằm trong BST "Thứ Sáu của Chị" của NTK Công Trí đã từng mở màn ấn tượng cho Tuần lễ Thời trang Quốc tế Thu Đông 2017, bạn thích phong cách của ai hơn?
#
# Quyền lực, tinh tế như ca sĩ Tóc Tiên hay có quyến rũ, tươi trẻ như Hoa hậu Ky Duyen
#
# #VIFW #VIFWFW #ThuSaucuaChi #Collection #CongTri #TocTien #KyDuyen #Designer #Singer
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Phủ sóng trên mọi mặt trận thời trang, từ sàn diễn ra ngoài đường phố, không thể phủ nhận rằng, checkered đang là họa tiết được các fashionista “mê đắm” nhất vào thời điểm hiện tại.
#
# #lofficielvietnam
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# 📸TRỌN BỘ BÍ KÍP LÊN MÀU CHUẨN TÂY #AFTERLIGHT
# Có sẵn bí kíp hết rồi mà không chịu chỉnh cho ảnh thêm chất Tây, thêm sang chảnh thì đừng xài xì mác phôn nữa nha 😆
# Check in Vietnam #afterlightfilter #yuna
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# 1) Astro Cha Eun Woo và Pristin Xiyeon sẽ rời vị trí MC của chương trình MBC ‘Musc Core’. Tập cuối cả 2 MC xuất hiện là 27.1
#
# 2) WJSN comeback vào tháng 2
#
# 3) Big Bang Seungri và đàn em IKON sẽ ghi hình ‘Knowing Brother’ vào ngày 25.1 đúng ngày IKON comeback
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Tấm vé chung kết Project Runway Vietnam tuyệt đẹp này sẽ được gửi đến tay những mem đã chiến thắng game Chia Sẻ Khoảnh Khắc Ngàn Like, thật quá may mắn và hạnh phúc phải không >.<
#
# Mem hãy chia sẻ thật nhiều thông tin, hình ảnh của chương trình để mau đến mốc 24.000 nhé ^_^
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# C ó một điều chắc chắn rằng, vào thời điểm Surface Phone được trình làng thì nó sẽ là một sản phẩm “có một không hai”, khác biệt hoàn toàn so với những chiếc điện thoại khác đang có mặt trên thị trường.
#
# #Genk
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Còn 20 ngày nữa là chúng ta được gặp 24 con người tài giỏi, dễ thương này ở tập đầu tiên rùi đấy cả nhà ạ. Cùng đếm ngược với Ad nào!!!
#
# Art Director: Cu-tie
# Photographer: Tee Lee
# Makeup: Maybelline NewYork
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Một số ứng dụng đang được miễn phí dành cho #Android. Hôm nay có khá nhiều app hay nhé các bạn, bao gồm #Mobile_Doc_Scanner (trị giá 114.000đ), #Social_Group_Service (trị giá 68.000đ), bộ tinh chỉnh âm thanh #Equalizer_Pro (trị giá 113.000đ) và một số icon pack đẹp mắt v.v...
# #techrum #techrum_freeapp #freeapp #mienphi #diendancongnghe
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Được xem là một trong những nơi ngắm bình minh đẹp nhất thế giới, bạn có muốn được ngồi ở trên khinh khí cầu và tận mắt nhìn thấy những tia nắng đầu tiên ở trên đất Bagan hay không? 😍😍😍
#
# #ellevn #ellevietnam #repost
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# Đã đến Ma Rốc, thì phải đến Marrakech, thành phố với những dãy núi tuyết hùng vĩ hằn trên dải trời xanh phía sau một ngọn tháp nhà thờ Hồi giáo đang vươn lên cao.
#
# Xem thêm ảnh và cẩm nang du lịch Marrakech trong album nha!
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Tối ngày 4/10, buổi họp báo phim "Sài Gòn Anh Yêu Em" đã diễn ra với sự tham gia của rất nhiều ngôi sao hàng đầu.
# Đặc biệt, diện trên mình những bộ áo dài với thiết kế tinh tế, bộ ba Quán quân của chương trình Vietnam's Next Top Model đã xuất hiện vô cùng nổi bật trên thảm đỏ và thu hút toàn bộ ánh nhìn của fan hâm mộ cũng như ống kính phóng viên!
#
# #NgocChau #HuongLy #NguyenOanh
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Ngỡ đâu muốn có những tấm hình lung linh cùng hoa nhất định phải lặn lội xa xôi lên tận Đà Lạt, nhưng giờ đối với dân Sài Gòn thì không cần nữa. Vì ngay thành phố phồn hoa này giờ đã có những “thiên đường” hoa giúp dân “sống ảo” vừa lên hình cực xinh, vừa chẳng phải đi xa.
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Hòn đảo này chẳng xa lạ mấy với những tín đồ ham mê dịch chuyển - Cù Lao Chàm (Quảng Nam). Không chỉ có biển xanh, cát trắng, từ giữa tháng 7 trở đi đây còn là “xứ sở” của loài hoa ngô đồng khoe sắc màu rực rỡ, phủ một lớp choàng đỏ lên những sườn núi.
#
# Tranh thủ phi ra đảo “sống ảo” ngay trước khi hoa tàn nào.
# #checkinculaocham #checkinquangnam #honie
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Xin phép ad cho bọn mình PR một chút ạ! :)
# Dành cho những ai yêu thích chương trình Eurovision, tụi mình mới lập page nhằm tạo ra một nơi để các bạn có thể vào bàn tán hay cập nhật tin tức từ chương trình ạ! :)
# Các bạn like page nhé! :D
# https://www.facebook.com/H%E1%BB%99i-nh%E1%BB%AFng-ng%C6%B0%E1%BB%9Di-th%C3%ADch-xem-Eurovision-1865101713747896/
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Năm 2011, không nhận được sự ủng hộ của gia đình và bạn bè, cô vay ngân hàng vài trăm triệu đồng với lãi suất cao để bắt đầu công ty của riêng mình với suy nghĩ “nếu thất bại thì đi làm thuê vài năm để trả nợ”.
#
# Và cô thất bại thật...
#
# #Genk
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Là một trong các Trung tâm thương mại (TTTM) đẳng cấp thế giới, Lotte Center Hà Nội sẽ là địa điểm kế tiếp có sự xuất hiện của BST Les Beiges đến từ thương hiệu mỹ phẩm Chanel.
#
# #ellevn #ellevietnam
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Giám đốc điều hành JPMorgan Chase Jamie Dimon gần đây gọi Bitcoin là trò lừa đảo và ám chỉ những người mua nó là “ngu ngốc”. Năm 2014, nhà đầu tư lừng danh Warren Buffett gọi Bitcoin là “ảo giác” đồng thời cảnh báo các nhà đầu tư nên “tránh xa” nó.
#
# Kể từ đó đến nay, Bitcoin đã tăng giá hơn chục lần....
#
# #Genk
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Beautiful moments at Vietnam International Fashion Week backstage with L'Oréal Professionnel and OHUI Vietnam
#
# Những giây phút đẹp tại hậu trường tuần lễ thời trang quốc tế Việt Nam với #lorealpro và #Ohui #vifw #vifw2016
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Kết Quả Giveaway nhân dịp page đạt 140k follow.
#
# Lúc mà Hannah tổng hợp danh sách xong là nhìn lại thấy follow đã gần 150k rồi, thật sự cám ơn các bạn đã yêu quý Na. Chắc phải chuẩn bị giveaway mới luôn quá :P
#
# Chúc mừng bạn Trần Hoài Thu đã là người may mắn, bạn inbox cho Hannah thông tin gửi quà nhé!
#
# Love,
# Hannah
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# 😲💥 Đi giữa ngân hà ở CÂY CẦU NGÀN SAO ở Sài Gòn 💫💫
#
# 🤩🌠 Sài Gòn cũng có cây cầu ngàn sao sống ảo siêu lung linh nèee
#
# Check in ở đây với gấu hay hội bạn thân là số dzách đó nha, các cậu check in chưa??? 😚❣️
#
# #VietnamTravel_SàiGòn #adminChang
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# LOVE SCENARIO của iKON lại đạt #1 tại Gaon Digital Chart tuần này. Đây là tuần thứ 4 ca khúc này nằm ngôi đầu bảng tại BXH này. Hiện tại chỉ có missA EXO và TWICE là các Group KPOP đạt được thành tích này. XIN CHÚC MƯNG 😍😍😍
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Giai điệu sôi động, bắt tai cực hợp không khí Xuân của Hồ Quang Hiếu với chất lượng lossless đỉnh cao. Ai fan "Con bướm xuân" thì không thể bỏ qua nhé 💓💓
#
# https://www.nhaccuatui.com/samsungfridayhits?st=5
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# Cần tìm Homestay Côn Đảo.
# Cả nhà cho mình hỏi chút, đã có ai đi Côn Đảo và ở homesay Uyên's House chưa ạ? Hay ai có homestay, khách sạn nào hay hay ngoài Côn Đảo cho mình xin ít review được không ạ.
# Cảm ơn cả nhà.
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# "sau một tháng mở cửa Expo 2012, Nhà triển lãm Việt Nam là một trong những nhà triển lãm thu hút đông khách tham quan nhờ không gian trưng bày thân thiện và chương trình biểu diễn nghệ thuật độc đáo, hấp dẫn. "
#
# Ôi chúa tôi, nó vít cái bài này như kiểu VN không có ai lết xác đến được cái triển lãm để biết cái sảnh đường của VN nó nhàm chán và xấu và vắng hiu hắt đến như thế nào ấy?
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Phong cách Gothic trở lại mùa thu này với những điểm nhấn cầu kì và lộng lẫy <3 <3 <3
#
# Đừng quên cập nhật các thông tin cực hot khác trên các fanpage Vietnam's Next Top Model Project Runway Vietnam beU Model Management nhé (y)
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Kết quả game: có gần 50 anh em gởi thông tin về, trong đó bạn Hiếu gởi về sớm nhất, lúc 16h33', với số cuối CMND: 476 trùng với giải đặc biệt đài Bạc Liêu (10/05/16) Chúc mừng bạn. Giải thưởng gồm:
# - Pin di động Anker 20.100 mAh, USB-C
# - Router Toto Link - N200RE
# - Ví Sen 2 từ Khắc tên
# - Link game: https://goo.gl/FoA1KE
#
# Anh em chưa may mắn trúng giải thì hẹn các game tiếp theo nhé :)
# #tinhte
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Hứa hẹn sẽ là một Tuần lễ Thời trang Quốc tế Việt Nam - VIFW SS 2018 đầy ấn tượng với các NTK hàng đầu Việt Nam và Quốc tế.
# Ngoài Công Trí thì mem trông đợi nhà nào nhất nào?
# 😍😍😍😍😍
# #VIFW #VIFWSS2018 #LotteLegendHotelSaigon #ChicilonMedia
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# [Rocks] Hôm nay sinh nhật Neyo đấy nhé, ;;). Ad sẽ giới thiệu qua về Neyo 1 chút, sau đó sẽ có 10 Request cho các mem nhanh nhất nhé, :x. REQUEST của NEYO thôi À NHAAAAAAA
#
# Neyo tên thật là Shaffer Chimere Smith, sinh ngày 18 tháng 10 1982, là một ca sĩ/nhạc sĩ/diễn viên/dancer và nhà sản xuất R&B của Mỹ đã từng giành giải 3 giải Grammy vào năm 2008 - 2009 và rất nhiều giải thưởng khác (BET, AMA, VMAs, ...).
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Chỉ còn vài giờ nữa, đêm trao giải thường niên ELLE Style Awards 2018 với chủ đề BE ALL YOU CAN BE sẽ diễn ra tại GEM Center, TPHCM. Bạn đã sẵn sàng?
#
# #ellevn #ellevietnam #esa2018 #ellestyleawards2018 #beallyoucanbe
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# 8 món ăn đường phố không thể bỏ qua ở Hong Kong <3
# Mực khổng lồ, cá viên chiên, dimsum, đậu phụ thối, và còn dồi rán nóng giòn, bún cuốn nóng hổi nữa...
# Tag người sẽ cùng bạn ăn sạch các khu chợ đêm ở Hong Kong nào
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# THIÊN ĐƯỜNG HOA TAM GIÁC MẠCH & 16 ĐIỂM CHECK
# Lạc vào Hà Giang như lạc vào mê cung của một xứ sở khác í, đẹp, yên bình, hùng vĩ và ngoạn mục tới nỗi không muốn về
# Check in Vietnam #Checkinhagiang #hagiang #tamgiacmach #yuna
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Như vậy là tạp chí Phái đẹp ELLE Việt Nam đã tròn 1 tuổi. Là tạp chí thời trang hàng đầu tại đây, ELLE vinh dự nhận được những lời chúc thật phong cách từ các nhà thiết kế đương đại của Việt Nam. Chúc mừng sinh nhật ELLE !
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# [NEW MV] I Don’t Wanna Live Forever - Zayn, Taylor Swift
# Clip có từ hôm qua rồi, mà vì 1 số lý do nên giờ Ghiền mới post lên cho chúng bạn và các mày cùng xem được :(
# Nói chung là clip có cả 2 anh chụy, nên xem, nên nghe, chấm hết :3
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Theo một báo cáo của công ty nghiên cứu eMarketer, mặc dù năm vừa rồi có nhiều thiết bị đeo đổ bộ thị trường, đồng thời chúng cũng trở nên lung linh như thứ đồ trang sức, nhưng tốc độ tăng trưởng toàn ngành vẫn đang giảm. Thực tế thì thiết bị đeo còn bị loa thông minh vượt qua, đặc biệt trong kỳ nghỉ lễ năm 2017.
#
# #Genk
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# KHI NGƯỜI MẪU LẤN SÂN.....BÁC SĨ
#
# Cô người mẫu Kate Naumova với chuyên môn là một bác sĩ đã sơ cứu cho nhà thiết kế Diễm My khi cô bị ngất xỉu sau khi nghe kết quả mình bị loại ở tập 5 của Project Runway.
#
# http://thongcaobaochi.com.vn/vn/news/bac-si-nhi-lan-san---nguoi-mau_5133.html
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Xa xăm bao nhiêu bao nhiêu ngày dài
# Đành quên yêu thương tương lai hiện tại...
# Bài hát " Ngày anh xa" do Miu Lê thể hiện, thân tặng bạn Vy Thúy. Chúc mọi người 1 buổi tối mát mẻ :p Các bạn yêu quý đừng sốt ruột, Ad sẽ đăng bài hát mọi người yêu cầu dần dần nhé ^_^
# http://www.nhaccuatui.com/bai-hat/ngay-anh-xa-miu-le.ySKrK6xapP6C.html
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Ad ơi. Mình đag tìm 1 bài hát mà mãi ko tìm ra..chỉ nhớ là của một boyband khá lớn tuổi rồi..trog MV thì có cảnh nv nữ chính cãi nhau xog chạy chiếc Ducati bỏ đi trên Highway rồi một a nv nam chính chạy đuổi theo bag chiếc Bulgati siêu đẹp, cảnh vật diễn ra ih hệt như trog giấc mơ của a ấy..:( mình có gắng nhớ mãi ko ra tên bài hát..:( Ad giúp mình nhé.Thanks a ton..
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# "Trong tình cảm, Tiên từng là người đầy rẫy lỗi lầm trong quá khứ nhưng Tiên tự hào về điều đó. Vì có những lỗi lầm đó, mình mới có ngày hôm nay và biết quý trọng những điều chân thành mà tình yêu đem lại."
# - Tiên Tiên -
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Sự xuất hiện của Samsung Flip hứa hẹn sẽ đem tới một góc nhìn hoàn toàn khác biệt về những văn phòng làm việc trong tương lại với những chiếc màn hình cỡ lớn và không gian trình diễn nội dung, tài liệu tiện lợi hơn.
#
# #Genk
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Giá này thì các dòng tầm trung khác phải dè chừng
# Zenfone Max Pro M1 Snapdragon 636, RAM từ 3GB - 6GB, Camera kép 16 Mp ,Camera selife từ 8 Mp - 16 Mp Face Unlock, Màn Full HD+, Pin 5000mAh, Android 8.1 Oreo giá từ 3.7 triệu VNĐ ( giá tại Ấn độ)
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Những thiết kế với cảm hứng menswear của #IHATEFASHION là ý tưởng vô cùng độc đáo và táo bạo mà chỉ I HATE FASHION - một thương hiệu với cảm hứng tới từ tinh thần Anh Quốc và những giá trị đáng tự hào và tôn vinh của nước Anh mới có tại #VIFW năm nay 👍👍👍
#
# #VIFWSS18 #VIFW2018
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Thông báo này được phát đi không lâu sau cuộc tập trung phản đối của các tài xế Uber, Grab tại trụ sở của hai công ty này tại Hà Nội nhằm mục đích yêu cầu giảm chiết khấu ăn chia và có các chính sách hỗ trợ tài xế trong việc cấm đường trên 13 tuyến phố vào giờ cao điểm hôm 15/1 vừa qua.
#
# #Genk
# --------------------------------------------------------------------------------
# True: technology
# Pred: fashion
# Nhân dịp ra mắt sản phẩm game mới, #Spandhead_Games đã quyết định tặng miễn phí cho người chơi bản quyền của #Stories_ThePathofDestinies trong thời gian ngắn, và sau khi nhận thành công, bạn sẽ sở hữu tựa game này một cách vĩnh viễn.
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Vũng Tàu ngoài những bãi biển đẹp, còn sở hữu rất nhiều địa điểm vui chơi, chụp choẹt cực đẹp mà không phải ai cũng biết. Nếu muốn check-in hết những điểm đến thú vị này, các bạn có thể tham khảo 10 điểm đến hot nhất Vũng Tàu dưới đây nhé!
# #checkinvungtau #Na
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# “Ngoài gia đình chúng ta ra, còn lại, đừng vội dốc lòng tin tưởng và quá đặt niềm hy vọng vào ai. Bởi chẳn ai đủ nhiều yêu thương và đủ nhiều cảm thông dành cho một người xa lạ.”
#
# (Ảnh: @piiaen)
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Vn-Zoom - Kiểm tra tài khoản google nhận thêm 2gb lưu trữ #Google Drive miễn phí
# B1: Truy cập http://bit.ly/Free2gbdrive-VN-Zoom
# B2: Kiểm tra tài khoản google của bạn trong thời gian vừa qua
#
# Với 2 bước trên tài khoản GOogle Drive của bạn sẽ được nhận thêm 2GB trọn đời.
#
# Lưu ý: Sau khi hoàn thành, các bạn đợi google cập nhật lại dung lượng nhé.
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Với Samsung, vị Chủ tịch cho rằng: "Chưa bao giờ Samsung được coi là một công ty phần mềm. Không có văn hóa của công ty phần mềm, có nhân lực thực sự có văn hóa về phần mềm như kiểu Microsoft hay là Apple hay là Bkav".
#
# #GenK
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Thường thì những người đã tu thiền ( hoặc tu một pháp môn nào đó) và đã nói là phi lợi nhuận thì sao Thầy lại thu tiền. Thầy phát tâm đi, ko lợi nhuân, ko thu tiền, phát tâm cho mọi người cùng tập theo Thầy, vì lợi ích chúng sinh đi!
# --------------------------------------------------------------------------------
# True: technology
# Pred: fashion
# #Android đang được miễn phí khá nhiều app ngon nhé các bạn, có #Fingerprint_Gestures (giúp tùy biến cảm biến vân tay), #nBubble_Elite (trả lời tin nhắn nhanh), #KLWP_theme và một số icon pack đẹp mắt khác.
# #techrum #techrum_freeapp #freeapp #mienphi #diendancongnghe
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Mem dự đoán ai sẽ là quán quân đầu tiên của Project Runway Vietnam nào?
# Comment ngay dưới ảnh này tên NTK mà bạn dự đoán, số lượng comment bạn dự đoán sẽ có, tag tên 5 người bạn và share ảnh này để có cơ hội giành 1 trong 5 giải thưởng tuyệt vời nhé!
#
# Mọi thông tin xin tham khảo note:
# https://www.facebook.com/notes/project-runway-vietnam/gameshow-d%E1%BB%B1-%C4%91o%C3%A1n-qu%C3%A1n-qu%C3%A2n/476478772434997
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Fan Quang Lê, Ngọc Sơn, Như Quỳnh, Phi Nhung bơi hết vào đây nào :3 :3 :3
# Hiếm có playlist nào mà " nghe phê không chỗ chê " từ đầu đến cuối như thế này <3
# http://www.nhaccuatui.com/playlist/nhac-tru-tinh-chon-loc-tuyet-pham-song-ca-tru-tinh-tau-ve-que-huong-va.fpY16QLxRMrq.html
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Xu hướng phim ca nhạc trở lại cho mùa Tết năm nay. Sự góp mặt hài hước với DON NGUYỄN làm Ông Chủ càng được dịp kịch tính và hot hơn~
#
# https://www.nhaccuatui.com/video/ong-chu-phim-ca-nhac-vu-duy-khanh.C85R86pYroDKD.html
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Obitmalware 5.3.0 sẽ giúp người sử dụng ngăn chặn
# - Các loại Ransomware Petya/GoldenEye
# - Tốc độ quét nhanh hơn 130% so với các phần mềm khác.
# - An toàn hớn khi duyệt web hoặc download
# - Bảo vệ sâu hơn , toàn diện trong thời gian thực
# Hiện phần mềm đang được tặng miễn phí tại đây
# http://bit.ly/2xWvalz
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Quang Hùng và Mâu Thuỷ cùng nhau có mặt tại đề cử người mẫu xuất sắc của tạp chí thời trang Elle. Đây là một niềm vui và tự hào của gia đình beU
# Hãy bình chọn cho Hùng và Thuỷ để cổ vũ tinh thần cho họ trong sự nghiệp người mẫu này mọi người nhé!
# #MauThuy #QuangHung #beUModels #ElleStyleAwards
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Không phụ lòng các tín đồ làm đẹp, makeup artist thân cận của Meghan Markle - Lydia Sellers đã tiết lộ những thông tin độc quyền nhất: Cô dâu Hoàng gia Anh mặc gì, làm đẹp như thế nào luôn là tâm điểm của mọi sự chú ý ở thời gian gần đây.
# --------------------------------------------------------------------------------
# True: technology
# Pred: fashion
# Đang diễn tập phòng thủ khu vực tỉnh Quảng Ninh, chuyển lực lượng vũ trang thành sẵn sàng chiến đấu , các địa phương vào trạng thái phòng thủ  sẵn sàng tác chiến. Anh em nào đi qua Quảng Ninh nghe tiếng bắn đừng giật mình nhé
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# Caro hay chấm bi gì thì hè này đều nhường lại cho cherry nhé 🍒🍒🍒 - họa tiết ngọt ngào, bánh bèo và không kém phần cuốn hút này đang lên ngôi khắp các mặt trận thời trang từ Tây sang Đông, ngay cả các người mẫu hàng đầu cũng mê mẩn luôn đấy. 🤩😘😍
# Bạn đã có cho mình một món đồ có họa tiết siêu hot mùa hè này chưa? 🤗
# #beUmodels #beUmgmt #streetstyle #springsummer2018 #cherry #trend
# --------------------------------------------------------------------------------
# True: fashion
# Pred: travel
# 🌟 DÀN MẪU NHÍ CỰC YÊU TẠI STREETSTYLE 🌟
#
# Đến từ các thương hiệu thời trang HAPPY clothings, Manan Vietnam,... các mẫu nhí cực kì sang choảng trong bộ đồ của mình 💕
#
# Cùng nhìn lại những hình ảnh xinh xắn, đáng yêu từ các bé nhé mem ✨✨✨
#
# #Thebeststreetstyle sẽ kéo dài từ 29/10 - 3/11 tại Tràng Tiền Plaza, đừng bỏ qua cơ hội thả ga pose dáng nhaaaa 💋
#
# #VIFW #FW2017 #VIFW2017
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Topic này sẽ tổng hợp những thủ thuật hữu ích trong khi sử dụng BlackBerry 10 từ kinh nghiệm sử dụng của mình, từ Internet, từ các thành viên và người dùng khắp nơi. Các bạn cứ mạnh dạn chia sẻ những điều thú vị nhé, mình sẽ cố gắng cập nhật vào topic này liên tục.
#
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# - "Tôi thích cậu"
# - "Tôi không thích cậu"
# - "Vậy... vậy để tôi nghĩ cách tiếp đã"
# ...
# ---
# Yêu lại tiếng Trung từ đầu tại: https://goo.gl/ER1d2h
# Có luôn nhập môn tiếng Hàn: https://goo.gl/GA2t4u
# Tiếng Nhật cũng có nếu bạn cần: https://goo.gl/KgH9fm
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Bộ sưu tập “ Coco Yêu Dấu “ của nhà thiết kế #CôngTrí lại được trình diễn một lần nữa tại EUROSPHERE #galadinner tối nay ! Thật tuyệt vời khi xem lại một lần nữa cảm xúc vẫn vẹn nguyên.
# Các bạn người mẫu của beU Model Management thật chuyên nghiệp và tỏa sáng phải không các bạn.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# 7 LOẠI THỰC PHẨM GIÚP THAI NHI TRẮNG HỒNG BẤT CHẤP GEN DI TRUYỀN 😍
#  Nhiều cặp vợ chồng có làn da không trắng nhưng vẫn sinh con da trắng bởi trong khi mang thai mẹ kiên trì ăn 8 loại thực phẩm sau:
#
# #pregnancy #beautiful #baby #coconut
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# Xin phép ad nhé. Mình đang tham dự cuộc thi này... Mọi người like và share giùm mình nhé. Thanks nhiều
#
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/709
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/708
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/707
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/706
#
# http://fitdesign.vn/anh-thi/1258#overlay=overlay/705
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Các bạn thân mến, trò chơi chia sẻ nhãn hiệu mascara yêu thích đã kết thúc. Kết quả sẽ được công bố vào 10:00 sáng mai, 2/11/2012. Ai sẽ là người nhận được mascara nhãn hiệu Estée Lauder (trị giá 750.000/cây)? Đón xem nhé!
#
# ------------------
# Thông tin thời trang và làm đẹp, truy cập: www.elle.vn
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Bước ra từ cuộc thi " thần tượng Bolero ", Đình Phước đã không làm khán giả và huấn luyện viên Quang Linh thất vọng khi liên tục cố gắng trong con đường ca hát và ra nhiều sản phẩm mới phục vụ khán giả. 😍
# Cả nhà cùng thưởng thức sản phẩm mới của Đình Phước nhé ;)
#
# http://www.nhaccuatui.com/video/noi-long-lang-tu-dinh-phuoc.N4VBwOqtTk3aT.html
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# Hi there,
# I really like your posts as they motivate me to do my job still better. I have noticed that you work with images very often. Im photographer & CEO of energepic.com - you can get there plenty licensed FREE photos of any category, hope it will be useful for your future projects even they're now perfect!
#
# Have a great & succesful day!
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Những từ còn thiếu quá dễ với bạn đúng hok hãy truy cập vào facebook Katy Perry Vietnam để tham gia trả lời câu hỏi và nhận được bộ CD + DVD Last Friday Night (Deluxe Single). Có tới 3 phần quà cho 3 bạn may mắn lên nhá !!!
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Thậm chí có cả kết nối Bluetooth và hỗ trợ điều khiển thông qua ứng dụng smartphone, một sự lựa rất tuyệt vời khi bạn muốn sạch sẽ tươm tất mà vẫn được nằm trên giường nướng thêm chút nữa :3
#
# #GenK
# --------------------------------------------------------------------------------
# True: fashion
# Pred: lifestyle
# Tuần lễ Thời trang Quốc tế Việt Nam không chỉ đem đến những show trình diễn đẳng cấp mà còn có 2 buổi hội thảo về kiến thức thời trang, được chia sẻ từ những chuyên gia hàng đầu trong ngành trong nước và quốc tế.
#
# #VIFW #VIFWFW2016 #VIFWHanoi #FutureNow
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Nhiều người nghĩ là đi du lịch thì khó mặc đẹp, vì phải mang nhiều đồ lỉnh kỉnh, lại phải di chuyển nhiều, rồi khó ủi đồ, vv...nhưng thật ra lúc đi du lịch mình vẫn có thể đẹp lồng lộn mà vẫn thoải mái. Có ai muốn biết bí kíp để mặc đẹp khi du lịch không? Na sẽ viết post chia sẻ nhé.
#
# PS. Hình Na tự chụp đó :)
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Chiều nay, cộng đồng A.R.M.Y đã đón nhận 2 tin vui. Đầu tiên là tài khoản Twitter của BTS đã cán mốc 10M theo dõi, trở thành tài khoản đầu tiên của Hàn Quốc đạt được điều này. Sau đó giờ thì MV Danger đã trở thành MV thứ 9 của nhóm đạt được 100M trên Youtube. Xin chúc mừng 😘😘😘😘
# |Cáo|
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Giải thưởng: Tai nghe Sennheiser, USB 3.0 Sandisk 64GB và Router Totolink N200RE đã được trao đến bạn Tâm chiến thắng game trong bài: [Hỏi Tinh tế] Về cách bố trí nút Back và Recent trên Android. Xin chúc mừng bạn!
# * Link bài: https://goo.gl/9mwF7G
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Trong lễ kỉ niệm 100 năm tuổi này, Hiệp hội Hoạt hình Nhật Bản (Association of Japanese Animations) đã cho ra mắt video dài 15 phút, tổng hợp toàn bộ những anime nổi bật đã ra đời kể từ khi tập anime đầu tiên được phát hành.
#
# #GenK
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Nhất định phải làm 1 bộ ảnh thật đẹp mẹ bầu nhỉ 😍😍
# ----------
# CÁC KHÓA HOC ƯU ĐÃI 70% - ĐĂNG KÝ KẺO LỠ MẸ NHA
# - Mẹ bầu học thai giáo cho con thông minh từ trong bụng:
# https://goo.gl/BHFRdm
# - Giáo dục sớm cho con giai đoạn 0-6 tuổi: https://goo.gl/qQM2ih
# - Dạy con đúng cách: https://goo.gl/7iWNvq
# - Ăn dặm kiểu Nhật: https://goo.gl/uMxZYN
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Hello mọi người, không biết mọi người có còn nhớ lần trước Hannah đã có một trải nghiệm khá táo bạo đó là lần đầu đổi style make up. Lần này Na được rủ chơi trò thử một ngày không xài tiền mặt. Mọi người theo dõi xem Na xử lý thế nào nha!
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# #FNC công ty chủ quản #FTISLAND #Minhwan xác nhận cậu và bạn đời #Yulhee đã chính thức đăng kí kết hôn hợp pháp và tiến tới kết hôn vào 19/10 năm nay
#
# Được biết Yulhee đã mang thai. Cặp đôi xác nhận mối quan hệ vào năm ngoái 2017
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# Quán Muối Tiêu Chanh với tiêu chí NGON - LẠ - BỔ - RẺ.
# Chúng tôi có những món đặc sản miền Tây, nhìn kinh hãi - ăn ngon vãi!!!
# Trân trọng kính mời quý khách đến 428 Đào Duy Từ, Kon Tum và cùng thưởng thức.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# SỨC MẠNH CỦA PHOTOSHOP
#
# Kristina Makeeva, một nhiếp ảnh gia và chuyên viên đồ hoạ của Nga đã khiến cả thế giới mê mẩn trước những bức hình tựa như cổ tích chỉ nhờ tài nghệ photoshop của mình. Mỗi bức ảnh, Kristina lại áp dụng một kỹ thuật photoshop khác nhau, mang đến những bức ảnh lung linh và chứng minh rằng tất cả mọi điều đều có thể thành hiện thực với PHOTOSHOP.
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Chúc mừng sinh nhật chàng trai của WANNABLE. Mong rằng những điều may mắn và tốt đẹp nhất sẽ đến với cậu. Hãy cố gắng trên con đường phía trước nhé. Mọi người sẽ luôn bên cậu 👌
# HAPPY BIRTHDAY PARK JIHOON 🎂🎂
# #HappyJihoonDay
# #박지훈_생일축하해
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# 😎[TỐI NAY NGHE GÌ]😎
#
# Phút chốc giải lao cho mùa FIFA đêm nay, thư giãn nhẹ cùng Soundtrack đậm chất World Cup thôi nào mấy đồng chí 🤩🤩🤩
# Nạp năng lượng nhẹ để cho những ngày còn thâu đêm suốt sáng chứ! 🤣🤣🤣
#
# https://www.nhaccuatui.com/playlist/fifa-world-cup-russia-2018-soundtrack-va.A1cAiXIBAym3.html
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# <3 8 HÀNH ĐỘNG THAY CHO LỜI NÓI I LOVE YOU <3
#
# Mỗi năm chỉ có một ngày Valentine. Nhưng các cặp đôi có thể biến những ngày bình thường trở thành lễ tình nhân bởi những hành động nhỏ nhưng không kém phần ngọt ngào, ấm áp. 😉
# #checkinVietnam #Tee
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Dưới đây là toàn bộ cụm từ thông dụng, bất di bất dịch không thay đổi.
#
# Đừng quên lưu cuốn bí kíp này để xài khi đi du lịch nhớ. Quan trọng cực kì đấy!! <3
#
# Nguồn: Langmaster
# #checkinvietnam #na
# --------------------------------------------------------------------------------
# True: travel
# Pred: music
# Away We Wow Launch Party
#
# Còn chưa đầy 48 nữa thôi cả nhà ơi! Chỗ ngồi rất giới hạn luôn nên ai có thiệp mời nhớ confirm để được xếp chỗ và nhận quà nha!
#
# We are launching in less than 48 hours! Seating is super limited so please RSVP to be seated & gifted if you are invited!
#
# #awaywewow #adrianandson #phanthiet #mercedesbenz
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Mỗi một mùa Hàn Quốc đều có một nét đẹp riêng hết nè. Lên lịch ghé thăm oppa và xứ sở kim chi thôi.
# #checkinvietnam #checkinhanquoc #yuna #KTOVietnam
# >>>https://visitkorea.org.vn/eventkorea/page/spring-event-mien-nam.html
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# UPDATINGGGGGGG
#
# Homestay là hình thức không mới, nhưng điều kiện để lựa chọn homestay của giới trẻ bây giờ không chỉ là giá cả mà còn phải đẹp và có khả năng làm background xịn trong ảnh check in nữa :))
# Dưới đây là list homestay trải khắp Việt Nam do check in Vietnam sưu tầm và sẽ update thường xuyên.
# Thông tin trong ảnh nhé.
# #checkinvietnam #Sunnies
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Chị em kế toán có gặp khó khăn với Excel không?
# Làm báo cáo có bao giờ bị lỗi mà chẳng biết lỗi ở đâu không?
# Hay là đọc đề bài tập Excel mà đọc tiếng Uzbekistan?
#
# Nếu còn nhiều thắc mắc liên quan đến Excel thì phải tham gia ngay Nhóm Thủ thuật Excel để được 10000 anh em cao thủ văn phòng hỗ trợ kịp thời nhé! Tham gia ngay thôi!
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# The collective collection from designer Cong Tri on L'Officiel Vietnam <3 Now that's amazing at its finest (y)
#
# Vietnam's Next Top Model beU Model Management Project Runway Vietnam
#
# Creative director: Dzung yoko
# Photographer: Mạnh Bi
# Make up & hair: Tung Chau Tran Model: Luth Seah Zhiqiang
# Dancer: Mai Trung Hiếu, Shu Nguyễn
# Produce: Cẩm Tú, Hensi Le.
# Set up by Hydan Decor, Lý Bình Sơn.
# L'Officiel Vietnam feature Designer Nguyen Cong Tri.
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Mình đang định mời 1 thầy giáo tiếng Anh người Anh dạy thêm Tiếng Anh giao tiếp vào 1-2 buổi tối ở Cầu Giấy. Mình cần 4 bạn nữa để mở 1 lớp học cùng mình... Bạn nào có nhu cầu liên lạc vs mình nhé - 0947014591
# ...
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# ❤️❤️❤️[CHIỀU NAY NGHE GÌ]❤️❤️❤️
# Thành phố chất chứa một trời thương nhớ....
# Thành phố của những linh hồn khắc khoải khôn nguôi
# Một thành phố, mang tên: EM! 💔💔💔
#
# https://www.nhaccuatui.com/bai-hat/thanh-pho-don-phuong-juun-dang-dung-ft-rtee.wD0pfHm9ya24.html
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# Danh sách phần mềm miễn phí trong đợt giveaway lần này. Bạn nào cần tải về dùng dần
# - IObit Uninstaller Pro 7
# - AdGuard for Windows
# - Soda PDF Anywhere
# - WonderFox DVD Ripper PRO
# - Photo Watermark Software
# - Heimdal PRO
# - Sticky Password
# - Magic Camera
# - Iris Pro
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Đến với Giọng ca của Hiền Thục vào 1 buổi tối thứ 6 qua khúc hát xưa quen thuộc mang lại cảm giác rất thư giãn phải không nè >>
#
# http://www.nhaccuatui.com/bai-hat/con-thuong-rau-dang-moc-sau-he-hien-thuc.a8lEPB3eCB79.html
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Đến với ELLE Fashion Show 2017, thảm đỏ thời trang của ELLE đã đón chào rất nhiều gương mặt khách mời thân thuộc. Hãy cùng điểm qua danh sách 10 bộ cánh thảm đỏ đẹp nhất của ELLE Fashion Show năm nay.
#
# #ellevn #ellevietnam #ELLEFashionJourney2017 #EFJ2017
# --------------------------------------------------------------------------------
# True: technology
# Pred: travel
# [TET18] Team Sài Gòn cũng cùng mối bận tâm khi Đà Lạt hay Vũng Tàu đông như kiến. Hãy tư vấn cho người anh em một địa điểm xịn đét đi chơi Tết nào!
#
# Anh em mê du lịch có vào: https://tinhte.vn/dulich/ để chia sẻ và hỗ trợ nhau nhé!
#
# #Tinhte #Tet18
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Dù yêu thích hay chán ghét Apple, nhưng đây vẫn là những con số khó có thể chối cãi !
# >> Apple Q4/2015: Tiếp tục phá kỷ lục
# http://genk.vn/tin-ict/30-nguoi-mua-iphone-trong-q4-2015-chuyen-sang-tu-android-ipad-pro-e-am-20151028110930903.chn
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# MỌI CÔ GÁI ĐỀU CẦN ĐI MỘT ĐÔI BOOT SÀNH ĐIỆU
#
# Đa phần con gái đều lăn tăn khi diện boots vì khá khó phối đồ. Tuy nhiên, những cách phối đồ với những đôi boots sành điệu dưới đây hẳn bạn phải mê tít.
#
# #LOfficiel, #LOfficielVietnam, #Fashion, #Boots
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Cùng điểm lại những khoảnh khắc đáng nhớ của ELLE  Fashion Show 2017 vừa diễn ra đêm qua!
#
# Mọi thông tin chi tiết được cập nhật trên fanpage ELLE Việt Nam và website elle.vn
#
# #ellevn #ellevietnam #ELLEFashionShow2017 #ELLEFashionJourney2017
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# ♪ [NGHE GÌ TRƯA NAY] ♪
#
# ♫ Một ca khúc thể loại tropical house với giai điệu rất catchy, cực bắt tai cực dễ nghe ;)
#
# NGHE NGAY ► http://www.nhaccuatui.com/bai-hat/try-me-jason-derulo-ft-jennifer-lopez-ft-matoma.QSqbs5pSYeCN.html
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Sự ngọt ngào của cặp soul-mate làng thời trang Việt Đoàn và Adrian Anh Tuấn, vốn không chỉ được đong đếm bởi những thành công chốn lụa là.
#
# Trên tất cả, Tuấn và Sơn khi nào cũng muốn cùng nhau trải nghiệm cuộc sống, đắm chìm trong những mật ngọt của tình yêu...
# --------------------------------------------------------------------------------
# True: fashion
# Pred: technology
# Việc làm việc theo nhóm tưởng dễ nhưng hóa ra lại là một thử thách “đau đầu” bởi khả năng lãnh đạo của trưởng nhóm cùng kĩ năng hòa hợp cùng nhau sẽ là yếu tố được đặt lên trên cùng. Bởi việc kết hợp các cá tính để đi theo một định hướng thống nhất là một việc không hề dễ dàng, đặc biệt là khả năng lãnh đạo của trưởng nhóm.
# --------------------------------------------------------------------------------
# True: travel
# Pred: fashion
# Không chỉ giảm giá cực mạnh, hàng loạt quán trà sữa quyết FREE sau chiến thắng của U23 Việt Nam
#
# Triệu hồi con bạn mê trà sữa hơn ăn cơm vào đây là chuẩn kèo 🇻🇳🇻🇳🇻🇳
# #checkinvietnam #honie
# --------------------------------------------------------------------------------
# True: music
# Pred: travel
# [ĐỘC QUYỀN][NEW MV]Tình Bơ Vơ - Tiêu Châu Như Quỳnh
# Tiêu Châu Như Quỳnh - cô nàng sở hữu chất giọng ngọt ngào vừa cho ra mắt MV trữ tình Tình Bơ Vơ với cảm xúc đong đầy trong từng câu hát.
# Cùng thưởng thức nhé cả nhà <3
# #NhaccuatuiDocQuyen
# #TinhBoVo
# #TieuChauNhuQuynh
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# [Rocks] Sau "No Drama" flop Tinashe tung "Faded Love" với sự tham gia của Future, :(. Đùa chứ chị hát hay nhảy đẹp mà sao chả ai quan tâm là thế nào nhỉ, :((. Mấy track này cũng catchy nữa chứ mờ, thôi mem vào tăng view cho chị đi, >:)
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Hình dáng kim cương "thay lời muốn nói" gì về tính cách của bạn?
#
# Không chỉ là luôn xuất hiện trong những gạch đầu dòng khao khát đầu tiên của phái đẹp, hình dáng viên kim cương còn thể hiện "gu" thẩm mỹ và tính cách của chủ nhân xinh đẹp sở hữu nó.
#
# #LOfficiel, #LOfficielVietnam
# --------------------------------------------------------------------------------
# True: music
# Pred: lifestyle
# Quang Linh là một ca sĩ chuyên hát về dòng nhạc dân ca, đặc biệt là dòng nhạc Huế. Ngoài ra, anh còn hát nhạc trẻ cũng như nhạc đương đại. Chim sáo ngày xưa là một trong những ca khúc thành công nhất của anh. Hãy cùng ad thưởng thức nhé
#
# https://www.nhaccuatui.com/samsungfridayhits?st=7
# --------------------------------------------------------------------------------
# True: music
# Pred: technology
# Máu lạnh thời gian quét trôi tất cả.
# Hối hả xoay chiều không gian để một lần được tìm về
# One Republic một lần nữa liệu có đốt cháy thính giả và fan hâm mộ sau bài hát này??? Check the HIT! ❤
#
# https://www.nhaccuatui.com/bai-hat/start-again-from-13-reasons-why-season-2-soundtrack-onerepublic-ft-logic.MATfN7fGiXOG.html
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Cho em hỏi: Có phần mềm nào quản lý các bài post trên mạng xã hội ko?
# Bữa trước em có đọc trên tinh tế, nhưng bị trôi bài mất, em tìm ko ra.
# Bài viết là Tổng hợp các công cụ tiện ích trên Internet gì gì đó, em ko rõ nữa!
# 09123 68861
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Skirt suits được các phu nhân, nữ chính khách coi như loại trang phục chuẩn mực để xuất hiện chính thức. Đây cũng là trang phục vô cùng phù hợp với các quý cô công sở đấy!
#
# Bạn đã sở hữu cho mình item này chưa?
#
# #ellevn #ellevietnam
# --------------------------------------------------------------------------------
# True: travel
# Pred: lifestyle
# Ninh Thuận ⛵ có lẽ là cái tên không còn quá xa lạ đối với những ai đam mê du lịch. Hãy cùng thử một lần đến vùng đất này xem nhé ^_^
# Chắc chắn bạn sẽ thích mê! <3
#
# Xem thêm album về Ninh Thuận của Check in Vietnam tại đây nha:
# http://on.fb.me/1pic5Bs
#
# #checkinninhthuan
# ---
# Source: kenh14.vn
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Designboom, tạp chí kiến trúc uy tín từ năm 1999, đã vinh danh 10 công trình tiêu biểu, có tác động tích cực đến xã hội của năm 2017. Công trình tầng thượng lọc không khí "Pavilion Of The Origins" của Hung Nguyen Architects đã vượt qua nhiều đối thủ nặng ký để lọt vào danh sách này.
#
# #Genk
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Chỉ sau 6 tuần khai trương, The World of Heineken đã đón tiếp vị khách thứ 10,000 tới trải nghiệm sự hoàn hảo, chứng tỏ sức hút cực lớn của địa điểm độc đáo này.
# Hãy đừng bỏ lỡ cơ hội trải nghiệm The World of Heineken khi bạn đặt chân tới Sài Gòn nhé.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: music
# BINGSU - ĐẬP TAN CƠN NÓNG MÙA HÈ
#
# Không phải ngẫu nhiên mà Bingsu được chọn làm món ăn tráng miệng yêu thích vào mùa hè. Thử tưởng tượng trong tiết trời nóng nực mà được thưởng thức một tô bingsu mát lạnh với những hương vị yêu thích như socola hay matcha thì còn gì bằng <3
#
# #ellevn #ellevietnam #bingsu
# --------------------------------------------------------------------------------
# True: fashion
# Pred: music
# Ai sẽ là Host của Project Runway Việt Nam??? Ad chắc chắn đây đang là câu hỏi mà tất cả mem nhà mình đang rất rất rất quan tâm phải không nào ^^
#
# http://projectrunway.com.vn/index.php/tin-tuc/10-ai-se-la-sieu-mau-heidi-klum-cua-project-runway-vietnam-2
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# Một cú hích lớn trong cộng đồng fan US UK và fan K-Pop khi ca khúc Ignite ra mắt với sự hợp tác của 4 cái tên nổi tiếng, trong đó có Alan Walker và Seung Ri - BigBang 😍😍
# Cháy quá cả nhà ơi ❗🔥
#
# https://www.nhaccuatui.com/bai-hat/ignite-k-391-ft-alan-walker-ft-julie-bergan-ft-seung-ri-bigbang.i4E3fRk3s6IB.html
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Bạn là người thích ngủ nướng. Bạn luôn mở mắt lúc 10 giờ sáng. Rồi bạn lại quay cuồng với son phấn, với đồ ăn đồ uống?
#
# Theo dõi bài viết này sẽ có những bí quyết làm đẹp buổi sáng dành cho bạn ~_^
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# - Người thì chi cả $230,000 một năm chỉ để chăm sóc mái tóc của mình...
#
# - Người thì chăm chỉ sử dũng liệu pháp nhau thai cừu đắt đỏ 6 tuần/lần.
#
# Bạn có đoán được đó là ai không?
#
# #LOfficielVietnam
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Có ai đang mệt mỏi vì Tết không? Na Tết năm nào cũng khoẻ re vì toàn đi du lịch thôi. Nhưng vì vậy mà đôi khi Na lại thấy buồn buồn vì cảm giác bị thiếu thiếu gì đó. Kiểu như bị mất gốc á.  Nên năm nay Na cũng muốn mình bận rộn hơn một tí để chuẩn bị đón tết cho có không khí.
#
# Mọi người xem tâm sự của Na, chị Đoan Trang, và Gào trong tập mới này về Tết nha.
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Không một ai có thể làm bạn hạnh phúc nếu bạn không cảm thấy hạnh phúc với chính bản thân mình. Đừng nhầm lẫn việc tìm kiếm tình yêu với tìm kiếm hạnh phúc. Hãy tìm kiếm hạnh phúc trước, rồi sau đó tìm người xứng đáng để chia sẻ hạnh phúc ấy cùng với bạn.
#
# - Steven Rosas
#
# #ellevn #ellevietnam
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Các bạn có nhu cầu tư vấn cấu hình máy tính hãy tham gia và đặt câu hỏi tại box tư vấn của diễn đàn nhé. Mod cuarGenK cùng rất nhiều thành viên nhiệt tình sẽ giúp bạn chọn được cấu hình ưng ý
# http://forum.genk.vn/forums/38/
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: fashion
# Lưu Diệc Phi, Dương Mịch và cả Suzy đều hóa thân làm người đẹp cổ trang rất xuất sắc, nhưng cô gái cuối cùng mới là đỉnh nhất nhé!!!
#
# #lofficielvietnam #fashion #cổ_trang #DuongMich #Luudiecphi #phambangbang #Rihanna
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Đây là một SimCity mới mang lại sự trung thực và chi tiết chưa từng có trong dòng game mô phỏng xây dưng. Đây cũng là game xây dựng thành phố có qui mô quản lý rộng nhất hiện nay, nơi bạn có thể kiểm soát một khu vực có quy mô gồm nhiều thành phố. Bạn có thể quản lý lên đến 16 thành phố một lần với các chuyên ngành khác nhau.
# >>>>http://goo.gl/Olnr7l
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Cuộc thi đã kết thúc giai đoạn nhận ảnh tham dự. Nhưng các bạn vẫn thể tiếp tục bình chọn cho tấm ảnh mình yêu thích đến ngày 14/02/2015.
#
# Kết quả sẽ được thông báo vào ngày 14/02/2015
#
# Cảm ơn mọi người ủng hộ cuộc thi ảnh Love Moments của ELLE nhé!
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: travel
# Xinh lung linh chỉ sau 3 phút makeup
# Ảo diệu quáaaaaa
# Chị em nào mê makeup mà chưa biết makeup kiểu gì cho xinh thì tham khảo ngay khóa học thần kỳ này tại đây nhé: https://goo.gl/zhzoP8
#
# ĐẶC BIỆT, ƯU ĐÃI 55% KHI THANH TOÁN BẰNG HÌNH THỨC CHUYỂN KHOẢN TẠI: https://goo.gl/zhzoP8
# --------------------------------------------------------------------------------
# True: lifestyle
# Pred: technology
# Hình từ bộ ảnh thời trang Cruise Trends
# Photographs: Alex Bramall - Styling: Linh Ly
# ELLE Việt Nam tổ chức thực hiện tại London và giữ bản quyền bộ hình này.
# Editor: Nguyen Danh Quy
# Người mẫu: Kwak Jiyoung @ Elite
# Trang điểm: Alex Babsky @ Jed Root sử dụng Lancôme
# Làm tóc: Stephen Beaver @ Jed Root sử dụng Kérastase
# Sản xuất: Amy Gutherie Production
# Trang phục: MAXMARA
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Đối với người dùng Android, việc thực hiện thao tác Root máy hoặc Flash ROM đều cần đến USB Driver tương ứng với mỗi thương hiệu riêng. Để giúp các bạn dễ dàng tìm kiếm hơn, TECHRUM đã tổng hợp liên kết tải về bộ cài đặt cho hầu hết smartphone Android như Samsung, LG, Sony, Google, HTC, Motorola, Dell, ZTE v.v...
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Hồi tuần trước, ứng dụng Nokia Creative Studio đã được chính thức cập nhật lên phiên bản 6.0 với nhiều sự thay đổi mới về giao diện người dùng cũng như các công cụ. Bản cập nhật mới này cũng còn thiếu đi tính năng Color Pop và điều chỉnh mắt đỏ. Hy vọng trong bản cập nhật tới chúng ta sẽ nhận được hai tính năng này.
#
# --------------------------------------------------------------------------------
# True: technology
# Pred: lifestyle
# Từ 1-6/6 đang có một triễn lãm vào cửa tự do cho những ai yêu Chùa, yêu sự thanh bình, tĩnh lặng, yêu danh thắng và con người Việt Nam hay chỉ đơn giản là yêu niềm đam mê của một người Pháp được hun đúc trên chính mảnh đất hình chữ S này.
#
# https://tinhte.vn/threads/moi-xem-trien-lam-anh-vietnam-pagodas-nicolas-cornet-tu-01-6-10-6-tai-sai-gon.2800414/
#
# #Tinhte #NicolasCornet
# --------------------------------------------------------------------------------
# True: travel
# Pred: technology
# Đầu tháng 6 mình có ra Ha nội chơi
# tối 6/11 mình đi - tối 11.6 về
# mình muốn ghé Ninh Bình chơi vs lại sapa
# mình nhờ các bạn tư vấn  góp ý cho mình hành trình đi như thế nào là hợp lý vs tiết kiệm nhất ạ
# cảm ơn.
# --------------------------------------------------------------------------------
# True: music
# Pred: fashion
# [panda] BREAKING NEWS:
# Lady Gaga đã kí hợp đồng thực hiện Vegas residency - theo đó má chỉ phải diễn 32 shows/năm, kéo dài trong 2 năm (74 shows tổng cộng) và nhận đc số tiền cực khủng lên đến $100M :O :O :O
# Diễn 1 show theater mà còn ăn tiền nhiều hơn diễn vài đêm arena :'( Kì này má Dậu quá lời :'( Talent always wins <3
# --------------------------------------------------------------------------------
# True: technology
# Pred: music
# - Xắt nó! http://genk.vn/internet/ung-cu-vien-donald-trump-khang-dinh-apple-nen-giup-toa-an-mo-khoa-iphone-20160218004434964.chn
# - Em like cho thím... http://genk.vn/tin-ict/mark-zuckerberg-bam-like-khi-apple-choi-ran-voi-fbi-va-chinh-phu-my-20160218005709505.chn
# --------------------------------------------------------------------------------
# Total: 1421
